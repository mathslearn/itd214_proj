# %% [markdown]
# Nanyang Polytechnic</br>
# Post-Diploma Certificate in Applied Data Science</br>
# ITD214 Applied Data Science Project</br>
# Wong Shao Mun (Admission Number: 1038987U)</br>
# 2 Mar 2025

# %%
# Mount drive.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read in csv file.

# Dataset from:
# Find Open Datasets and Machine Learning Projects | Kaggle
# https://www.kaggle.com/datasets?search=reviews
# Hotel Reviews
# https://www.kaggle.com/datasets/datafiniti/hotel-reviews

import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ITD214/Datafiniti_Hotel_Reviews_Jun19.csv')
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
#
#                           address  \
# 0                 5620 Calle Real
# 1  5th And San Carlos PO Box 3574
# 2  5th And San Carlos PO Box 3574
# 3  5th And San Carlos PO Box 3574
# 4  5th And San Carlos PO Box 3574
#
#                                           categories  \
# 0  Hotels,Hotels and motels,Hotel and motel mgmt....
# 1                               Hotels,Lodging,Hotel
# 2                               Hotels,Lodging,Hotel
# 3                               Hotels,Lodging,Hotel
# 4                               Hotels,Lodging,Hotel
#
# ...

# %%
# Check shape of df.

print("Shape:", df.shape)
print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print()

# Check datatypes of df.

print("df.dtypes:")
print(df.dtypes)
print()
# Out:
# Shape: (10000, 26)
# Number of rows: 10000
# Number of columns: 26
#
# df.dtypes:
# id                       object
# dateAdded                object
# dateUpdated              object
# address                  object
# categories               object
# primaryCategories        object
# city                     object
# country                  object
# keys                     object
# latitude                float64
# longitude               float64
# name                     object
# postalCode               object
# province                 object
# reviews.date             object
# reviews.dateAdded       float64
# reviews.dateSeen         object
# reviews.rating            int64
# reviews.sourceURLs       object
# reviews.text             object
# reviews.title            object
# reviews.userCity         object
# reviews.userProvince     object
# reviews.username         object
# sourceURLs               object
# websites                 object
# dtype: object

# %%
print("df:")
print('Count number of rows with non-empty values:')
print(df.count())
print()
print('Count number of rows with null values:')
print(df.isnull().sum())
print()
# Out:
# df:
# Count number of rows with non-empty values:
# id                      10000
# dateAdded               10000
# dateUpdated             10000
# address                 10000
# categories              10000
# primaryCategories       10000
# city                    10000
# country                 10000
# keys                    10000
# latitude                10000
# longitude               10000
# name                    10000
# postalCode              10000
# province                10000
# reviews.date            10000
# reviews.dateAdded           0
# reviews.dateSeen        10000
# reviews.rating          10000
# reviews.sourceURLs      10000
# reviews.text            10000
# reviews.title            9999
# reviews.userCity        10000
# reviews.userProvince     9998
# reviews.username        10000
# sourceURLs              10000
# websites                10000
# dtype: int64
#
# Count number of rows with null values:
# id                          0
# ...

# %%
# Check number of duplicate rows in df.
# Duplicate rows found.

duplicate_rows_df = df[df.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_df.shape[0])
duplicate_rows_df
# Out:
# Number of duplicate rows:  210
#                         id             dateAdded           dateUpdated  \
# 540   AWEKmgyt3-Khe5l_exCm  2018-01-18T18:45:51Z  2019-05-20T05:37:48Z
# 1052  AVwear0JkufWRAb5CuHZ  2015-12-01T19:33:20Z  2019-05-18T06:15:05Z
# 1264  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# 1266  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# 1267  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# ...                    ...                   ...                   ...
# 9490  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9491  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9493  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9495  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9530  AV6atrNyIxWefVJwqtKq  2017-09-19T15:15:43Z  2018-12-08T16:07:53Z
#
#                        address  \
# 540         2904 Washington Rd
# ...

# %%
print('Count number of duplicate rows:', df.duplicated().sum())
print()
print('Count number of duplicate rows with id value:', df['id'].duplicated().sum())
print()
print('Count number of duplicate rows with reviews.text value:', df['reviews.text'].duplicated().sum())
print()
print('Count number of duplicate rows with reviews.title value:', df['reviews.title'].duplicated().sum())
print()
# Out:
# Count number of duplicate rows: 210
#
# Count number of duplicate rows with id value: 8567
#
# Count number of duplicate rows with reviews.text value: 230
#
# Count number of duplicate rows with reviews.title value: 1529

# %%
# Identify duplicate rows with keep='first' (this marks duplicates as True except for the first occurrence).
duplicates_to_drop = df.duplicated(keep='first') # This shows all rows, each with its Boolean result, True or False.
# display(duplicates_to_drop)
print(f"Rows to be dropped:")
duplicates_to_drop_list = df[df.duplicated(keep='first')] # This shows all rows to be dropped.
display(duplicates_to_drop_list)
print()

# Calculate the number of rows to be dropped.
num_rows_to_drop = duplicates_to_drop.sum()
print(f"Number of rows to be dropped: {num_rows_to_drop}")
num_rows_to_drop1 = duplicates_to_drop_list.shape[0]
print(f"Number of rows to be dropped: {num_rows_to_drop1}")
num_rows_to_drop2 = len(duplicates_to_drop_list)
print(f"Number of rows to be dropped: {num_rows_to_drop2}")
print()

# Drop the duplicated rows directly from df.
df = df[~duplicates_to_drop]

# Reset the index of df.
df.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame.
print("DataFrame after dropping duplicated rows and reindexing:")
display(df)
# Out:
# Rows to be dropped:
#                         id             dateAdded           dateUpdated  \
# 540   AWEKmgyt3-Khe5l_exCm  2018-01-18T18:45:51Z  2019-05-20T05:37:48Z
# 1052  AVwear0JkufWRAb5CuHZ  2015-12-01T19:33:20Z  2019-05-18T06:15:05Z
# 1264  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# 1266  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# 1267  AVwchAIHIN2L1WUflybT  2015-11-06T09:24:17Z  2019-05-17T01:39:09Z
# ...                    ...                   ...                   ...
# 9490  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9491  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9493  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9495  AVweNseC_7pvs4fzBCjZ  2017-04-06T17:49:11Z  2018-12-18T05:56:05Z
# 9530  AV6atrNyIxWefVJwqtKq  2017-09-19T15:15:43Z  2018-12-08T16:07:53Z
#
#                        address  \
# 540         2904 Washington Rd
# ...

# %%
# Check number of duplicate rows in df['reviews.text'].

import pandas as pd

# Find all duplicate rows (including the first occurrence).
duplicate_rows_df = df[df['reviews.text'].duplicated(keep=False)]  # keep=False marks all duplicates

# Sort duplicates to group identical rows together.
duplicate_rows_df = duplicate_rows_df.sort_values(by=list(df.columns))

# Print number of duplicate rows.
print("Number of duplicate rows:", duplicate_rows_df.shape[0])

# Display duplicate rows stacked on top of one another.
duplicate_rows_df
# Out:
# Number of duplicate rows: 24
#                         id             dateAdded           dateUpdated  \
# 5438  AV1eT1uE3-Khe5l_NHZp  2017-07-20T04:44:05Z  2019-03-22T07:59:17Z
# 3404  AV1eTOBYa4HuVbed6vjj  2017-07-20T04:41:22Z  2019-05-07T09:37:06Z
# 3403  AV1eTOBYa4HuVbed6vjj  2017-07-20T04:41:22Z  2019-05-07T09:37:06Z
# 7467  AV1eUFlyIxWefVJwfdod  2017-07-20T04:45:10Z  2019-02-17T13:07:12Z
# 89    AV1thhZpIxWefVJwhDL7  2017-07-23T03:38:10Z  2019-05-20T16:15:57Z
# 1699  AV5aIOzq3-Khe5l_Vh3X  2017-09-07T02:16:33Z  2019-05-15T00:11:29Z
# 1692  AV5aIOzq3-Khe5l_Vh3X  2017-09-07T02:16:33Z  2019-05-15T00:11:29Z
# 4009  AVwdbLuSkufWRAb55xAj  2016-05-07T01:36:38Z  2019-04-20T09:26:51Z
# 9447  AVwdk4zOByjofQCxqeEN  2017-03-31T20:40:26Z  2018-12-04T15:29:16Z
# 9458  AVwdk4zOByjofQCxqeEN  2017-03-31T20:40:26Z  2018-12-04T15:29:16Z
# 8810  AVwebW3tIN2L1WUf40LS  2016-06-04T23:00:01Z  2018-12-25T05:07:31Z
# 8804  AVwebW3tIN2L1WUf40LS  2016-06-04T23:00:01Z  2018-12-25T05:07:31Z
# ...

# %%
df.shape
# Out:
# (9790, 26)

# %%
# Drop row with index 3404 because it is the same as row with index 3403.

df = df.drop(index=3404)

# %%
df.shape
# Out:
# (9789, 26)

# %%
# Drop 18 rows where reviews.text=MoreMore.

# Assuming 'df' is your DataFrame from the provided code
df = df[df['reviews.text'] != 'MoreMore']

# %%
df.shape
# Out:
# (9771, 26)

# %%
# Groupby df['reviews.rating'] in a table and show total of all counts.

import pandas as pd

# Group by 'reviews.rating' and count occurrences
rating_counts = df.groupby('reviews.rating').size().reset_index(name='count')

# Calculate the total count
total_count = rating_counts['count'].sum()

# Add a new row for the total
total_row = pd.DataFrame({'reviews.rating': ['Total'], 'count': [total_count]})

# Concatenate the total row to the rating counts table
rating_counts = pd.concat([rating_counts, total_row], ignore_index=True)

# Display the table with the total count
rating_counts
# Out:
#   reviews.rating  count
# 0              1    554
# 1              2    536
# 2              3   1163
# 3              4   2801
# 4              5   4717
# 5          Total   9771

# %%
# Check for extreme, illogical or suspicious values for numerical variables.
# No extreme, illogical or suspicious values found.
print('df.describe():')
print(df.describe())
# Out:
# df.describe():
#           latitude    longitude  reviews.dateAdded  reviews.rating
# count  9771.000000  9771.000000                0.0     9771.000000
# mean     34.983012  -101.646668                NaN        4.083922
# std       6.364696    20.216892                NaN        1.150906
# min      19.438604  -159.480300                NaN        1.000000
# 25%      29.957700  -117.888954                NaN        4.000000
# 50%      33.804844   -95.619149                NaN        4.000000
# 75%      38.946400   -84.371578                NaN        5.000000
# max      64.843590   -71.073340                NaN        5.000000

# %%
# Ensure 'reviews.date' is in datetime format
df['reviews.date'] = pd.to_datetime(df['reviews.date'], format='ISO8601') # alternative for ISO8601 format

# Extract year, month, day and weekofyear from 'reviews.date'.
df['year'] = df['reviews.date'].dt.year
df['month'] = df['reviews.date'].dt.month
df['day'] = df['reviews.date'].dt.day
df['weekofyear'] = df['reviews.date'].dt.isocalendar().week

# Extract day of the week (e.g., Mon, Tue, etc.)
df['day_of_week'] = df['reviews.date'].dt.strftime('%a')  # Short format (Mon, Tue)
# df['day_of_week'] = df['reviews.date'].dt.day_name()   # Full format (Monday, Tuesday)

# Apply one-hot encoding for df['day_of_week'] column.
df = pd.get_dummies(df, columns=['day_of_week'], dtype=int)
#df = pd.get_dummies(df, columns=['day_of_week'])
#df = pd.get_dummies(df, columns=['day_of_week']).astype(int)

print(df.head())
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
#
#                           address  \
# 0                 5620 Calle Real
# 1  5th And San Carlos PO Box 3574
# 2  5th And San Carlos PO Box 3574
# 3  5th And San Carlos PO Box 3574
# 4  5th And San Carlos PO Box 3574
#
#                                           categories  \
# 0  Hotels,Hotels and motels,Hotel and motel mgmt....
# 1                               Hotels,Lodging,Hotel
# 2                               Hotels,Lodging,Hotel
# 3                               Hotels,Lodging,Hotel
# 4                               Hotels,Lodging,Hotel
#
# ...

# %%
desired_order = [
    'day_of_week_Mon', 'day_of_week_Tue', 'day_of_week_Wed',
    'day_of_week_Thu', 'day_of_week_Fri', 'day_of_week_Sat', 'day_of_week_Sun'
]

# Reorder columns while keeping other columns unchanged
# You can reorder the columns in your DataFrame using reindex or by manually specifying the order.
# Solution: Reorder Columns
# This ensures that:
# • All non-day_of_week columns stay in their original order.
# • The day_of_week_* columns are reordered correctly.
df = df[[col for col in df.columns if col not in desired_order] + desired_order]

# Reorder columns while keeping other columns unchanged
# Using insert Method
# If you want to reposition the columns in place, you can use .pop() and .insert() (which you already prefer for DataFrame modifications 😉)
# for col in desired_order:
#     df.insert(len(df.columns), col, df.pop(col))
# IndexError: index 36 is out of bounds for axis 0 with size 35

print(df)
# Out:
#                         id             dateAdded           dateUpdated  \
# 0     AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1     AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2     AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3     AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4     AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# ...                    ...                   ...                   ...
# 9785  AVwdatg0ByjofQCxo5S5  2017-04-14T05:04:33Z  2018-12-02T13:36:35Z
# 9786  AVwdatg0ByjofQCxo5S5  2017-04-14T05:04:33Z  2018-12-02T13:36:35Z
# 9787  AVwdatg0ByjofQCxo5S5  2017-04-14T05:04:33Z  2018-12-02T13:36:35Z
# 9788  AV1thTgM3-Khe5l_OvT5  2017-07-23T03:37:13Z  2018-12-02T00:27:00Z
# 9789  AV1tg9C7a4HuVbed8XA5  2017-07-23T03:35:41Z  2018-12-01T21:24:24Z
#
#                              address  \
# 0                    5620 Calle Real
# ...

# %%
# Do one line graph for each year where vertical axis is sum of number of rows for df["reviews.rating'] and horizontal axis is month.
# Overlay line graphs for year. Start horizontal axis with 1 and end with 12 with each interval as 1.
# Change horizontal axis labels to Jan, Feb, Mar, ...

import matplotlib.pyplot as plt

# Group data by year and month, then sum the ratings
yearly_ratings = df.groupby(['year', 'month'])['reviews.rating'].sum().reset_index()

# Create the line plot
plt.figure(figsize=(12, 6))

for year in yearly_ratings['year'].unique():
    year_data = yearly_ratings[yearly_ratings['year'] == year]
    plt.plot(year_data['month'], year_data['reviews.rating'], label=str(year))

# Customize the plot
plt.xlabel('Month')
plt.ylabel('Sum of Ratings')
plt.title('Sum of Ratings per Month for Each Year')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Do bar graph for each year where vertical axis is sum of number of rows for df["reviews.rating'] and horizontal axis is year.
# Colour within each bar the different df['reviews.rating'].
# Label sum total for each df['reviews.rating'] in the middle of coloured section.
# Label sum total for total number of rows for df["reviews.rating'] at top of bar.

import matplotlib.pyplot as plt

# Group data by year and rating, then count the occurrences
rating_counts = df.groupby(['year', 'reviews.rating'])['reviews.rating'].count().unstack()

# Create the bar plot
rating_counts.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews per Rating per Year')
plt.xticks(rotation=0)
plt.legend(title='Rating')

# Annotate the bars with the total count for each year
for i, year in enumerate(rating_counts.index):
    total_count = rating_counts.loc[year].sum()
    plt.text(i, total_count, str(int(total_count)), ha='center', va='bottom')

# Annotate each segment with its count, handling NaN values
for i, year in enumerate(rating_counts.index):
    bottom = 0
    for rating in rating_counts.columns:
        count = rating_counts.loc[year, rating]
        # Check if count is NaN and replace with 0 for annotation
        if pd.isna(count):
            count = 0
        plt.text(i, bottom + count / 2, str(int(count)), ha='center', va='center')
        bottom += count

plt.tight_layout()
plt.show()

# %%
# Do bar graph for each year where vertical axis is percentage of number of rows for df["reviews.rating'] and horizontal axis is year.
# Colour within each bar the different df['reviews.rating'].
# Label percentage total for each df['reviews.rating'] in the middle of coloured section.
# Label percentage total for total number of rows for df["reviews.rating'] and sum total for total number of rows for df["reviews.rating'] at top of bar.

import matplotlib.pyplot as plt

# Group data by year and rating, then calculate the percentage of each rating for each year
rating_percentages = df.groupby(['year', 'reviews.rating'])['reviews.rating'].count().unstack()
rating_percentages = rating_percentages.div(rating_percentages.sum(axis=1), axis=0) * 100

# Create the bar plot
ax = rating_percentages.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Percentage of Reviews')
plt.title('Percentage of Reviews per Rating per Year')
plt.xticks(rotation=0)
plt.legend(title='Rating')

# Annotate each segment with its percentage
for i, year in enumerate(rating_percentages.index):
    bottom = 0
    for rating in rating_percentages.columns:
        percentage = rating_percentages.loc[year, rating]
        if pd.notna(percentage):  # Check for NaN values
            plt.text(i, bottom + percentage / 2, f'{percentage:.1f}%', ha='center', va='center')
        bottom += percentage

# Annotate the bars with the total percentage for each year (which should always be 100%)
for i, year in enumerate(rating_percentages.index):
    total_percentage = rating_percentages.loc[year].sum()
    plt.text(i, total_percentage, f'{total_percentage:.1f}%', ha='center', va='bottom')

# Calculate and display the total number of reviews for each year at the top of the bar
total_reviews_per_year = df.groupby('year')['reviews.rating'].count()
for i, year in enumerate(rating_percentages.index):
    total_count = total_reviews_per_year[year]
    ax.text(i, rating_percentages.loc[year].sum() + 2, str(int(total_count)), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Do a count for df['reviews.rating'].

# print(df['reviews.rating'].value_counts())

# Do a count for df['reviews.rating'] and sort by df['reviews.rating'].

# Count the occurrences of each rating and sort by rating.
rating_counts = df['reviews.rating'].value_counts().sort_index()

print(rating_counts)
# Out:
# reviews.rating
# 1     554
# 2     536
# 3    1163
# 4    2801
# 5    4717
# Name: count, dtype: int64

# %%
# Print first 20 rows of df[review.ratings], df[reviews.title], df[reviews.text] where df[reviewws.ratings]==3
# Can see that reviews.text for reviews.rating == 3 is negative sentiment, so will code as negative sentiment.

# Filter for rows where 'reviews.rating' is equal to 3
filtered_df = df[df['reviews.rating'] == 3]

# Select the desired columns and print the first 20 rows
#print(filtered_df[['reviews.rating', 'reviews.title', 'reviews.text']].head(20))
print(filtered_df[['reviews.rating', 'reviews.text']].head(20))
# Out:
#      reviews.rating                                       reviews.text
# 0                 3  This hotel was nice and quiet. Did not know, t...
# 2                 3  Parking was horrible, somebody ran into my ren...
# 11                3  I stayed here for three nights while I explore...
# 13                3  The water is very hot and there's no cold wate...
# 18                3  The Whitney Hotel is ideally located to see mo...
# 45                3  The bar closed at 10pm which was poorOnly 3 da...
# 86                3  We stayed here after traveling through Rocky M...
# 98                3  The issues started the first night. Do Not sta...
# 105               3  If you are driving then this is for you! A bit...
# 106               3  First impression, I see vehicles parked tightl...
# 113               3  The hotel staff was friendly and engaging. The...
# 115               3  I had a friend in town, so was looking for a S...
# ...

# %%
# Print first 10 rows of df[review.ratings], df[reviews.title], df[reviews.text] of each df[review.ratings] where df[reviewws.ratings]==1, 2, 3, 4, 5 and sort rows by df[reviewws.ratings].
# Upon inspection, will code reviews.ratings == 1, 2, 3 as negative sentiment and 4, 5 as positive sentiment.

# Assuming 'df' is already defined and loaded as in the provided code.

# Create an empty list to store the results
all_ratings_data = []

# Loop through each rating value (1 to 5)
for rating in range(1, 6):
    # Filter the DataFrame for the current rating
    filtered_df = df[df['reviews.rating'] == rating]

    # Select the desired columns
    selected_columns = filtered_df[['reviews.rating', 'reviews.title', 'reviews.text']]

    # Get the first 10 rows
    top_10 = selected_columns.head(10)

    # Append the data for the current rating to the list
    all_ratings_data.append(top_10)

# Concatenate the results into a single DataFrame
result_df = pd.concat(all_ratings_data)

# Sort the DataFrame by 'reviews.rating'
result_df = result_df.sort_values('reviews.rating')

# Print the resulting DataFrame
result_df
# Out:
#      reviews.rating                                      reviews.title  \
# 6                 1                 Does not live up to its reputation
# 7                 1                        worst customer service ever
# 9                 1                        The worst place i've booked
# 26                1  Horrible, closet like rooms with no air condit...
# 30                1        In the valet parking they stole in the car.
# 34                1  Great service from Staff but the hotel needs a...
# 36                1                             Beauty is not the best
# 84                1   Please switch to reusable plates and silverware!
# 94                1                racist / rude loss prevention team.
# 116               1                                      Rooms smelled
# 165               2                                            Insects
# 150               2             Normally like Hamptons - not this one!
# ...

# %%
# Add df['sentiment'] where df['sentiment']=1 where df['reviews.rating']==4, 5 and df['sentiment']=0 where df['reviews.rating']==1, 2, 3.

# Create the 'sentiment' column based on 'reviews.rating'
#df['sentiment'] = 0  # Initialize the column with 0
df.loc[df['reviews.rating'].isin([1, 2, 3]), 'sentiment'] = 0 # 0 for negative sentiments.
df.loc[df['reviews.rating'].isin([4, 5]), 'sentiment'] = 1 # 1 for positive sentiment.

# Convert to integer
df['sentiment'] = df['sentiment'].astype(int)

# %%
print(df[['reviews.rating', 'sentiment']])
# Out:
#       reviews.rating  sentiment
# 0                  3          0
# 1                  4          1
# 2                  3          0
# 3                  5          1
# 4                  2          0
# ...              ...        ...
# 9785               4          1
# 9786               5          1
# 9787               5          1
# 9788               5          1
# 9789               4          1
#
# [9771 rows x 2 columns]

# %%
# Check that reviews.ratings == 1, 2, 3 as negative sentiment and 4, 5 as positive sentiment are coded correctly.
# Upon inspection, coding done correctly.

# Do a count for df['reviews.rating'], groupby df['sentiment']. Sort df['reviews.rating'].

# Group by 'sentiment' and count the occurrences of each 'reviews.rating'
rating_counts_by_sentiment = df.groupby('sentiment')['reviews.rating'].value_counts().sort_index()

rating_counts_by_sentiment
# Out:
# sentiment  reviews.rating
# 0          1                  554
#            2                  536
#            3                 1163
# 1          4                 2801
#            5                 4717
# Name: count, dtype: int64

# %%
# Count occurrences of each 'reviews.rating' within 'sentiment' and sort
rating_counts_by_sentiment = df.groupby('sentiment')['reviews.rating'].value_counts().sort_index()

# Convert to DataFrame
rating_counts_df = rating_counts_by_sentiment.reset_index(name='count')

# Calculate percentage within each sentiment group
# The problem is here: the groupby creates a multi-index,
# and apply returns a series with that multi-index.
# You need to reset the index before assigning it back to the dataframe.
rating_counts_df['percentage'] = rating_counts_df.groupby('sentiment')['count'].apply(lambda x: 100 * x / x.sum()).reset_index(level=0, drop=True)

# Display result
print(rating_counts_df)
# Out:
#    sentiment  reviews.rating  count  percentage
# 0          0               1    554   24.589436
# 1          0               2    536   23.790502
# 2          0               3   1163   51.620062
# 3          1               4   2801   37.257249
# 4          1               5   4717   62.742751

# %%
# @title
# Count occurrences of each 'reviews.rating' within 'sentiment' and sort
rating_counts_by_sentiment = df.groupby('sentiment')['reviews.rating'].value_counts().sort_index()

# Convert to DataFrame
rating_counts_df = rating_counts_by_sentiment.reset_index(name='count')

# Calculate percentage out of all rows in df
total_rows = len(df)
rating_counts_df['percentage'] = 100 * rating_counts_df['count'] / total_rows

# Display result
print(rating_counts_df)
# Out:
#    sentiment  reviews.rating  count  percentage
# 0          0               1    554    5.669839
# 1          0               2    536    5.485621
# 2          0               3   1163   11.902569
# 3          1               4   2801   28.666462
# 4          1               5   4717   48.275509

# %%
# Do a count for df['sentiment'] and sort by df['sentiment'].

# Count the occurrences of each sentiment and sort by sentiment.
rating_counts = df['sentiment'].value_counts().sort_index()

print(rating_counts)
# Out:
# sentiment
# 0    2253
# 1    7518
# Name: count, dtype: int64

# %%
# Count the occurrences of each 'sentiment'
sentiment_counts = df['sentiment'].value_counts()

# Convert to DataFrame
sentiment_counts_df = sentiment_counts.reset_index(name='count')
sentiment_counts_df.columns = ['sentiment', 'count']  # Rename columns for clarity

# Calculate the percentage of each sentiment out of the total rows
total_rows = len(df)
sentiment_counts_df['percentage'] = 100 * sentiment_counts_df['count'] / total_rows

# Sort by sentiment
sentiment_counts_df = sentiment_counts_df.sort_values(by='sentiment')

# Display the result
print(sentiment_counts_df)
# Out:
#    sentiment  count  percentage
# 1          0   2253   23.058029
# 0          1   7518   76.941971

# %%
# Do one line graph for each year where vertical axis is sum of number of rows where df["sentiment']=0 and horizontal axis is month.
# Overlay line graphs for year. Start horizontal axis with 1 and end with 12 with each interval as 1.
# Change horizontal axis labels to Jan, Feb, Mar, ...

import matplotlib.pyplot as plt

# Group the data by year and month, then count the number of rows where sentiment is 0
sentiment_counts = df[df['sentiment'] == 0].groupby(['year', 'month'])['sentiment'].count().reset_index()

# Create the line plot
plt.figure(figsize=(12, 6))

for year in sentiment_counts['year'].unique():
    year_data = sentiment_counts[sentiment_counts['year'] == year]
    plt.plot(year_data['month'], year_data['sentiment'], label=str(year))

# Customize the plot
plt.xlabel('Month')
plt.ylabel('Number of rows where sentiment = 0')
plt.title('Number of rows with sentiment = 0 (negative) per month for each year')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Do one line graph for each year where vertical axis is sum of number of rows where df["sentiment']=1 and horizontal axis is month.
# Overlay line graphs for year. Start horizontal axis with 1 and end with 12 with each interval as 1.
# Change horizontal axis labels to Jan, Feb, Mar, ...

import matplotlib.pyplot as plt

# Group the data by year and month, then count the number of rows where sentiment is 1
sentiment_counts = df[df['sentiment'] == 1].groupby(['year', 'month'])['sentiment'].count().reset_index()

# Create the line plot
plt.figure(figsize=(12, 6))

for year in sentiment_counts['year'].unique():
    year_data = sentiment_counts[sentiment_counts['year'] == year]
    plt.plot(year_data['month'], year_data['sentiment'], label=str(year))

# Customize the plot
plt.xlabel('Month')
plt.ylabel('Number of rows where sentiment = 1')
plt.title('Number of rows with sentiment = 1 (positive) per month for each year')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(True)
plt.show()

# %%
# Do bar graph for each year where vertical axis is sum of number of rows for df["sentiment'] and horizontal axis is year.
# Colour within each bar the different df['sentiment'].
# Label sum total for each df['sentiment'] in the middle of coloured section.
# Label sum total for total number of rows for df["sentiment'] at top of bar.

import matplotlib.pyplot as plt

# Group data by year and rating, then count the occurrences
rating_counts = df.groupby(['year', 'sentiment'])['sentiment'].count().unstack()

# Create the bar plot
rating_counts.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews per Sentiment per Year')
plt.xticks(rotation=0)
plt.legend(title='Rating')

# Annotate the bars with the total count for each year
for i, year in enumerate(rating_counts.index):
    total_count = rating_counts.loc[year].sum()
    plt.text(i, total_count, str(int(total_count)), ha='center', va='bottom')

# Annotate each segment with its count, handling NaN values
for i, year in enumerate(rating_counts.index):
    bottom = 0
    for rating in rating_counts.columns:
        count = rating_counts.loc[year, rating]
        # Check if count is NaN and replace with 0 for annotation
        if pd.isna(count):
            count = 0
        plt.text(i, bottom + count / 2, str(int(count)), ha='center', va='center')
        bottom += count

plt.tight_layout()
plt.show()

# %%
# Do bar graph for each year where vertical axis is percentage of number of rows for df["sentiment'] and horizontal axis is year.
# Colour within each bar the different df['sentiment'].
# Label percentage total for each df['sentiment'] in the middle of coloured section.
# Label percentage total for total number of rows for df["sentiment'] and sum total for total number of rows for df["sentiment'] at top of bar.

import matplotlib.pyplot as plt

# Group data by year and rating, then calculate the percentage of each rating for each year
rating_percentages = df.groupby(['year', 'sentiment'])['sentiment'].count().unstack()
rating_percentages = rating_percentages.div(rating_percentages.sum(axis=1), axis=0) * 100

# Create the bar plot
ax = rating_percentages.plot(kind='bar', stacked=True, figsize=(10, 6))

# Customize the plot
plt.xlabel('Year')
plt.ylabel('Percentage of Reviews')
plt.title('Percentage of Reviews per Sentiment per Year')
plt.xticks(rotation=0)
plt.legend(title='Rating')

# Annotate each segment with its percentage
for i, year in enumerate(rating_percentages.index):
    bottom = 0
    for rating in rating_percentages.columns:
        percentage = rating_percentages.loc[year, rating]
        if pd.notna(percentage):  # Check for NaN values
            plt.text(i, bottom + percentage / 2, f'{percentage:.1f}%', ha='center', va='center')
        bottom += percentage

# Annotate the bars with the total percentage for each year (which should always be 100%)
for i, year in enumerate(rating_percentages.index):
    total_percentage = rating_percentages.loc[year].sum()
    plt.text(i, total_percentage, f'{total_percentage:.1f}%', ha='center', va='bottom')

# Calculate and display the total number of reviews for each year at the top of the bar
total_reviews_per_year = df.groupby('year')['sentiment'].count()
for i, year in enumerate(rating_percentages.index):
    total_count = total_reviews_per_year[year]
    ax.text(i, rating_percentages.loc[year].sum() + 2, str(int(total_count)), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Heatmap shows sentiment to be highly positively correlated to reviews.rating which
# is expected as sentiment is a derived variable of reviews.rating.

# Correlation heatmap for df.
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
# correlation_matrix = df.corr()
correlation_matrix = df.select_dtypes(include=['number']).corr()

# Print or display the correlation matrix
print(correlation_matrix)
print()

# Create the heatmap
# plt.figure(figsize=(12, 10))  # Adjust figure size as needed
plt.figure(figsize=(12, 4))  # Adjust figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of df')
plt.show()
# Out:
#                    latitude  longitude  reviews.dateAdded  reviews.rating  \
# latitude           1.000000  -0.040659                NaN       -0.005287
# longitude         -0.040659   1.000000                NaN       -0.019539
# reviews.dateAdded       NaN        NaN                NaN             NaN
# reviews.rating    -0.005287  -0.019539                NaN        1.000000
# year               0.007496   0.056304                NaN        0.083800
# month              0.043324  -0.033965                NaN       -0.014708
# day                0.004643   0.020385                NaN       -0.014662
# weekofyear         0.042766  -0.028557                NaN       -0.020426
# day_of_week_Mon   -0.009310   0.000686                NaN        0.024222
# day_of_week_Tue   -0.004160   0.011347                NaN       -0.002076
# day_of_week_Wed   -0.000004  -0.007617                NaN        0.003261
# day_of_week_Thu   -0.017793  -0.001327                NaN       -0.003337
# ...

# %%
# Column 'primaryCategories' identified as potential feature to be selected for modelling.

# Print unique values in columns of df.
# for col in df.columns:
#   print(f"Unique values in column '{col}': {df[col].unique()}")

# Print unique values in columns of df where unique values are <= 50
for col in df.columns:
  unique_values = df[col].nunique()
  if unique_values <= 50:
    print(f"Unique values in column '{col}': {df[col].unique()}")
# Out:
# Unique values in column 'primaryCategories': ['Accommodation & Food Services'
#  'Accommodation & Food Services,Arts Entertainment & Recreation'
#  'Accommodation & Food Services,Administrative & Support & Waste Management & Remediation'
#  'Accommodation & Food Services,Agriculture']
# Unique values in column 'country': ['US']
# Unique values in column 'province': ['CA' 'KY' 'LA' 'CO' 'IL' 'IN' 'FL' 'AK' 'GA' 'AL' 'AZ' 'AR' 'OR' 'WA'
#  'UT' 'TX' 'TN' 'SC' 'PA' 'OH' 'NY' 'NM' 'MD' 'MI' 'MS' 'MO' 'IA' 'WI'
#  'HI' 'VA' 'ID' 'NV' 'WV' 'WY' 'KS' 'MN' 'NE' 'ND' 'DE' 'OK' 'NC' 'MT'
#  'SD' 'RI' 'NJ' 'MA']
# Unique values in column 'reviews.dateAdded': [nan]
# Unique values in column 'reviews.rating': [3 4 5 2 1]
# Unique values in column 'year': [2018 2016 2015 2014 2017 2019 2011 2009 2013 2012 2005 2010 2007 2008
#  2004 2006 2003]
# Unique values in column 'month': [ 1  4  8  3  7 11  6  9 10  5 12  2]
# ...

# %%
# Count unique values for df['primaryCategories'].

print(df['primaryCategories'].nunique())
# Out:
# 4

# %%
# Print unique values for df['primaryCategories'].

print(df['primaryCategories'].unique())
# Out:
# ['Accommodation & Food Services'
#  'Accommodation & Food Services,Arts Entertainment & Recreation'
#  'Accommodation & Food Services,Administrative & Support & Waste Management & Remediation'
#  'Accommodation & Food Services,Agriculture']

# %%
# Data by primaryCategories too highly imbalanced so will not be selected as feature to model.
# Count number for each unique value of df['primaryCategories'].

# Count the occurrences of each unique value in 'primaryCategories'
category_counts = df['primaryCategories'].value_counts()

# Print the result
print(category_counts)
# Out:
# primaryCategories
# Accommodation & Food Services                                                              9762
# Accommodation & Food Services,Arts Entertainment & Recreation                                 7
# Accommodation & Food Services,Administrative & Support & Waste Management & Remediation       1
# Accommodation & Food Services,Agriculture                                                     1
# Name: count, dtype: int64

# %%
# Declare features, X with columns: year, month, day, weekofyear, day_of_week_Mon, day_of_week_Tue,
# day_of_week_Wed, day_of_week_Thu, day_of_week_Fri, day_of_week_Sat, day_of_week_Sun.
x = df[['year', 'month', 'day', 'weekofyear', 'day_of_week_Mon', 'day_of_week_Tue', 'day_of_week_Wed',
        'day_of_week_Thu', 'day_of_week_Fri', 'day_of_week_Sat', 'day_of_week_Sun']]

print("x.shape:", x.shape)
print("x:")
print(x)
print()

# Declare target variable, Y with column: sentiment.
y = df['sentiment']

print("y.shape:", y.shape)
print("y:")
print(y)
print()
# Out:
# x.shape: (9771, 11)
# x:
#       year  month  day  weekofyear  day_of_week_Mon  day_of_week_Tue  \
# 0     2018      1    1           1                1                0
# 1     2016      4    2          13                0                0
# 2     2016      1    6           1                0                0
# 3     2016      8   22          34                1                0
# 4     2016      3   21          12                1                0
# ...    ...    ...  ...         ...              ...              ...
# 9785  2015     12   24          52                0                0
# 9786  2015     11   17          47                0                1
# 9787  2016      7    6          27                0                0
# 9788  2016     10   26          43                0                0
# 9789  2017      6   29          26                0                0
#
#       day_of_week_Wed  day_of_week_Thu  day_of_week_Fri  day_of_week_Sat  \
# ...

# %%
# itd213_20241104_diabetes-Student Copy.ipynb
# itd213_20241104_Topic 9 - ScikitLearn - Incomes - Unguided - Student Copy.ipynb

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
models = []

# K-Nearest Neighbors (No random_state needed)
models.append(('KNC(n=5)', KNeighborsClassifier(n_neighbors=5)))
models.append(('KNC(n=10)', KNeighborsClassifier(n_neighbors=10)))
models.append(('KNC(n=15)', KNeighborsClassifier(n_neighbors=15)))
models.append(('KNC(n=20)', KNeighborsClassifier(n_neighbors=20)))
models.append(('KNC(n=25)', KNeighborsClassifier(n_neighbors=25)))
models.append(('KNC(n=30)', KNeighborsClassifier(n_neighbors=30)))
models.append(('KNC(n=35)', KNeighborsClassifier(n_neighbors=35)))
models.append(('KNC(n=40)', KNeighborsClassifier(n_neighbors=40)))
models.append(('KNC(n=45)', KNeighborsClassifier(n_neighbors=45)))
models.append(('KNC(n=50)', KNeighborsClassifier(n_neighbors=50)))

# Support Vector Machine (SVC)
models.append(('SVM', SVC(gamma='auto', random_state=42)))  # Added random_state
# models.append(('SVM - Linear', SVC(kernel='linear', gamma='auto', random_state=42)))  # Added random_state
# models.append(('SVM - Quadratic Polynomial', SVC(kernel='poly', degree=2, gamma='auto', random_state=42)))  # Uncomment if needed
# models.append(('SVM - Cubic Polynomial', SVC(kernel='poly', degree=3, gamma='auto', random_state=42)))  # Uncomment if needed

# Logistic Regression
models.append(('LR', LogisticRegression(solver='liblinear', random_state=42)))  # Added random_state

# Decision Trees
models.append(('DT(min_samples_split=2)', DecisionTreeClassifier(random_state=42)))  # Added random_state
models.append(('DT(min_samples_samples split=10)', DecisionTreeClassifier(min_samples_split=10, random_state=42)))  # Added random_state
models.append(('DT(min_samples_samples split=20)', DecisionTreeClassifier(min_samples_split=20, random_state=42)))  # Added random_state
models.append(('DT(min_samples_samples split=30)', DecisionTreeClassifier(min_samples_split=30, random_state=42)))  # Added random_state

# Naive Bayes (No random_state needed)
models.append(('GNB', GaussianNB()))

# Random Forest (Already has random_state ✅)
models.append(('RF(n=5)', RandomForestClassifier(n_estimators=5, random_state=42)))
models.append(('RF(n=10)', RandomForestClassifier(n_estimators=10, random_state=42)))
models.append(('RF(n=15)', RandomForestClassifier(n_estimators=15, random_state=42)))
models.append(('RF(n=20)', RandomForestClassifier(n_estimators=20, random_state=42)))
models.append(('RF(n=25)', RandomForestClassifier(n_estimators=25, random_state=42)))
models.append(('RF(n=30)', RandomForestClassifier(n_estimators=30, random_state=42)))

# Gradient Boosting (Added random_state)
models.append(('GB', GradientBoostingClassifier(random_state=42)))  # Added random_state

# %%
# Import train_test_split and accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score

# %%
# Simple validation
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2,
    stratify = y, random_state=42)

# %%
print("x.shape:", x.shape)
print("x_train.shape:", x_train.shape)
print("x_test.shape:", x_test.shape)
print()
print("y.shape:", y.shape)
print("y_train.shape:", y_train.shape)
print("y_test.shape:", y_test.shape)
# Out:
# x.shape: (9771, 11)
# x_train.shape: (7816, 11)
# x_test.shape: (1955, 11)
#
# y.shape: (9771,)
# y_train.shape: (7816,)
# y_test.shape: (1955,)

# %%
score_list = []

for name, model in models:
    print(name)
    model.fit(x_train, y_train) # all training happens here
    y_pred = model.predict(x_test)
    score = accuracy_score(y_test, y_pred)
    score_list.append(score)
    print(score)
# Out:
# KNC(n=5)
# 0.7232736572890025
# KNC(n=10)
# 0.7391304347826086
# KNC(n=15)
# 0.760613810741688
# KNC(n=20)
# 0.7647058823529411
# KNC(n=25)
# 0.7687979539641944
# KNC(n=30)
# 0.7682864450127878
# KNC(n=35)
# 0.769309462915601
# KNC(n=40)
# 0.769309462915601
# KNC(n=45)
# 0.769309462915601
# KNC(n=50)
# 0.769309462915601
# SVM
# 0.7672634271099744
# LR
# 0.769309462915601
# DT(min_samples_split=2)
# 0.6557544757033248
# DT(min_samples_samples split=10)
# 0.6838874680306906
# DT(min_samples_samples split=20)
# 0.69923273657289
# DT(min_samples_samples split=30)
# 0.7115089514066496
# GNB
# 0.759079283887468
# RF(n=5)
# 0.6884910485933504
# RF(n=10)
# 0.6915601023017903
# RF(n=15)
# 0.6997442455242967
# RF(n=20)
# 0.7048593350383632
# RF(n=25)
# 0.7028132992327366
# RF(n=30)
# 0.7063938618925831
# GB
# 0.7672634271099744

# %%
# No undersampling.

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score
import pandas as pd
import numpy as np

# Initialize lists to store results
results = []  # Store results for each model as dictionaries

# Define skf before using it
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Loop through the models
for name, model in models:
    print(f"Evaluating model: {name}")

    # Initialize lists to store metrics for cross-validation
    model_cv_scores = []

    # Cross-validation loop to calculate CV accuracy scores
    for train_index, test_index in skf.split(x, y):
        # Split data into training and testing sets
        x_train, x_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Fit model on the original training data (no undersampling)
        model.fit(x_train, y_train)

        # Make predictions for the test set of the fold
        y_test_pred = model.predict(x_test)

        # Calculate and store test accuracy (CV)
        test_accuracy = accuracy_score(y_test, y_test_pred)
        model_cv_scores.append(test_accuracy)

    # After cross-validation, calculate the mean CV accuracy
    mean_cv_accuracy = np.mean(model_cv_scores)

    # Train the model on the entire training data
    model.fit(x_train, y_train)

    # Calculate metrics for the entire training data (outside of the CV loop)
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Calculate train accuracy, test accuracy, train precision, and test precision
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_precision = precision_score(y_train, y_train_pred, average='weighted')
    test_precision = precision_score(y_test, y_test_pred, average='weighted')

    # Store results for this model as a dictionary
    results.append({
        'Model': name,
        'Cross-Validation Accuracy Scores': [round(score, 4) for score in model_cv_scores],  # Store CV scores from folds
        'Mean CV Accuracy': round(mean_cv_accuracy, 4),  # Store mean CV accuracy
        'Train Accuracy': round(train_accuracy, 4),  # Train accuracy (after entire training data)
        'Test Accuracy': round(test_accuracy, 4),  # Test accuracy (on hold-out test set)
        'Train Precision': round(train_precision, 4),  # Train precision (after entire training data)
        'Test Precision': round(test_precision, 4)   # Test precision (on hold-out test set)
    })

# Create a DataFrame from the results
df_results = pd.DataFrame(results)

# Display the results
print(df_results)
# Out:
# Evaluating model: KNC(n=5)
# Evaluating model: KNC(n=10)
# Evaluating model: KNC(n=15)
# Evaluating model: KNC(n=20)
# Evaluating model: KNC(n=25)
# Evaluating model: KNC(n=30)
# Evaluating model: KNC(n=35)
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluating model: KNC(n=40)
# ...

# %%
df_results
# Out:
#                                Model  \
# 0                           KNC(n=5)
# 1                          KNC(n=10)
# 2                          KNC(n=15)
# 3                          KNC(n=20)
# 4                          KNC(n=25)
# 5                          KNC(n=30)
# 6                          KNC(n=35)
# 7                          KNC(n=40)
# 8                          KNC(n=45)
# 9                          KNC(n=50)
# 10                               SVM
# 11                                LR
# 12           DT(min_samples_split=2)
# 13  DT(min_samples_samples split=10)
# 14  DT(min_samples_samples split=20)
# 15  DT(min_samples_samples split=30)
# 16                               GNB
# 17                           RF(n=5)
# 18                          RF(n=10)
# 19                          RF(n=15)
# 20                          RF(n=20)
# 21                          RF(n=25)
# 22                          RF(n=30)
# 23                                GB
#
# ...

# %%
# Sort df using df['Mean CV Accuracy'].

# Sort the DataFrame by 'Mean CV Accuracy' in descending order
df_results = df_results.sort_values(by='Test Accuracy', ascending=False)

df_results
# Out:
#                                Model  \
# 6                          KNC(n=35)
# 7                          KNC(n=40)
# 8                          KNC(n=45)
# 9                          KNC(n=50)
# 11                                LR
# 5                          KNC(n=30)
# 23                                GB
# 10                               SVM
# 4                          KNC(n=25)
# 16                               GNB
# 2                          KNC(n=15)
# 3                          KNC(n=20)
# 1                          KNC(n=10)
# 15  DT(min_samples_samples split=30)
# 0                           KNC(n=5)
# 19                          RF(n=15)
# 21                          RF(n=25)
# 14  DT(min_samples_samples split=20)
# 20                          RF(n=20)
# 22                          RF(n=30)
# 18                          RF(n=10)
# 17                           RF(n=5)
# 13  DT(min_samples_samples split=10)
# 12           DT(min_samples_split=2)
#
# ...

# %%
# Confusion matrix for KNC(n=35)

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'x_train', 'y_train', 'x_test', 'y_test', and 'models' are defined as in the previous code

# Find the KNC(n=35)
for name, model in models:
  if name == 'KNC(n=35)':
    knc_30_model = model
    break

# Fit the model (if not already fitted)
knc_30_model.fit(x_train, y_train)

# Predict on the test set
y_pred = knc_30_model.predict(x_test)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for KNC(n=35)')
plt.show()

# %%
# Undersampling of the majority class (sentiment=1) in the training set.

from sklearn.model_selection import StratifiedKFold
from sklearn.utils import resample  # Import the resample function from sklearn.utils
from sklearn.metrics import accuracy_score, precision_score
import pandas as pd
import numpy as np

# Initialize lists to store results
results = []  # Store results for each model as dictionaries

# Define skf before using it
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Loop through the models
for name, model in models:
    print(f"Evaluating model: {name}")

    # Initialize lists to store metrics for cross-validation
    model_cv_scores = []

    # Cross-validation loop to calculate CV accuracy scores
    for train_index, test_index in skf.split(x, y):
        # Split data into training and testing sets
        x_train, x_test = x.iloc[train_index], x.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]

        # Undersample the majority class (sentiment=1) in the training set
        x_train_resampled, y_train_resampled = resample(
            x_train[y_train == 1], y_train[y_train == 1],
            replace=False, n_samples=(y_train == 0).sum(), random_state=42
        )
        x_train_resampled = pd.concat([x_train[y_train == 0], x_train_resampled])
        y_train_resampled = pd.concat([y_train[y_train == 0], y_train_resampled])

        # Fit model on the resampled data
        model.fit(x_train_resampled, y_train_resampled)

        # Make predictions for the test set of the fold
        y_test_pred = model.predict(x_test)

        # Calculate and store test accuracy (CV)
        test_accuracy = accuracy_score(y_test, y_test_pred)
        model_cv_scores.append(test_accuracy)

    # After cross-validation, calculate the mean CV accuracy
    mean_cv_accuracy = np.mean(model_cv_scores)

    # Train the model on the entire resampled training data
    model.fit(x_train_resampled, y_train_resampled)

    # Calculate metrics for the entire training data (outside of the CV loop)
    y_train_pred = model.predict(x_train_resampled)
    y_test_pred = model.predict(x_test)

    # Calculate train accuracy, test accuracy, train precision, and test precision
    train_accuracy = accuracy_score(y_train_resampled, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    train_precision = precision_score(y_train_resampled, y_train_pred, average='weighted')
    test_precision = precision_score(y_test, y_test_pred, average='weighted')

    # Store results for this model as a dictionary
    results.append({
        'Model': name,
        'Cross-Validation Accuracy Scores': [round(score, 4) for score in model_cv_scores],  # Store CV scores from folds
        'Mean CV Accuracy': round(mean_cv_accuracy, 4),  # Store mean CV accuracy
        'Train Accuracy': round(train_accuracy, 4),  # Train accuracy (after entire training data)
        'Test Accuracy': round(test_accuracy, 4),  # Test accuracy (on hold-out test set)
        'Train Precision': round(train_precision, 4),  # Train precision (after entire training data)
        'Test Precision': round(test_precision, 4)   # Test precision (on hold-out test set)
    })

# Create a DataFrame from the results
df_results = pd.DataFrame(results)

# Display the results
print(df_results)
# Out:
# Evaluating model: KNC(n=5)
# Evaluating model: KNC(n=10)
# Evaluating model: KNC(n=15)
# Evaluating model: KNC(n=20)
# Evaluating model: KNC(n=25)
# Evaluating model: KNC(n=30)
# Evaluating model: KNC(n=35)
# Evaluating model: KNC(n=40)
# Evaluating model: KNC(n=45)
# Evaluating model: KNC(n=50)
# Evaluating model: SVM
# Evaluating model: LR
# Evaluating model: DT(min_samples_split=2)
# Evaluating model: DT(min_samples_samples split=10)
# Evaluating model: DT(min_samples_samples split=20)
# Evaluating model: DT(min_samples_samples split=30)
# Evaluating model: GNB
# Evaluating model: RF(n=5)
# Evaluating model: RF(n=10)
# Evaluating model: RF(n=15)
# Evaluating model: RF(n=20)
# Evaluating model: RF(n=25)
# Evaluating model: RF(n=30)
# Evaluating model: GB
#                                Model  \
# 0                           KNC(n=5)
# 1                          KNC(n=10)
# 2                          KNC(n=15)
# 3                          KNC(n=20)
# ...

# %%
df_results
# Out:
#                                Model  \
# 0                           KNC(n=5)
# 1                          KNC(n=10)
# 2                          KNC(n=15)
# 3                          KNC(n=20)
# 4                          KNC(n=25)
# 5                          KNC(n=30)
# 6                          KNC(n=35)
# 7                          KNC(n=40)
# 8                          KNC(n=45)
# 9                          KNC(n=50)
# 10                               SVM
# 11                                LR
# 12           DT(min_samples_split=2)
# 13  DT(min_samples_samples split=10)
# 14  DT(min_samples_samples split=20)
# 15  DT(min_samples_samples split=30)
# 16                               GNB
# 17                           RF(n=5)
# 18                          RF(n=10)
# 19                          RF(n=15)
# 20                          RF(n=20)
# 21                          RF(n=25)
# 22                          RF(n=30)
# 23                                GB
#
# ...

# %%
# Sort df using df['Mean CV Accuracy'].

# Sort the DataFrame by 'Mean CV Accuracy' in descending order
df_results = df_results.sort_values(by='Test Accuracy', ascending=False)

df_results
# Out:
#                                Model  \
# 16                               GNB
# 11                                LR
# 23                                GB
# 10                               SVM
# 6                          KNC(n=35)
# 19                          RF(n=15)
# 8                          KNC(n=45)
# 4                          KNC(n=25)
# 17                           RF(n=5)
# 21                          RF(n=25)
# 18                          RF(n=10)
# 20                          RF(n=20)
# 22                          RF(n=30)
# 13  DT(min_samples_samples split=10)
# 2                          KNC(n=15)
# 14  DT(min_samples_samples split=20)
# 9                          KNC(n=50)
# 0                           KNC(n=5)
# 12           DT(min_samples_split=2)
# 7                          KNC(n=40)
# 15  DT(min_samples_samples split=30)
# 5                          KNC(n=30)
# 3                          KNC(n=20)
# 1                          KNC(n=10)
#
# ...

# %%
# Confusion matrix for GNB

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'x_train', 'y_train', 'x_test', 'y_test', and 'models' are defined as in the previous code

# Find the GNB
for name, model in models:
  if name == 'GNB':
    gnb_model = model
    break

# Fit the model (if not already fitted)
gnb_model.fit(x_train, y_train)

# Predict on the test set
y_pred = gnb_model.predict(x_test)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for GNB')
plt.show()

# %%
print(df.shape)
# Out:
# (9771, 38)

# %%
df2 = df.copy()

# %%
print(df2.shape)
# Out:
# (9771, 38)

# %%
print(df2.columns)
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'name', 'postalCode', 'province', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username', 'sourceURLs', 'websites',
#        'year', 'month', 'day', 'weekofyear', 'day_of_week_Mon',
#        'day_of_week_Tue', 'day_of_week_Wed', 'day_of_week_Thu',
#        'day_of_week_Fri', 'day_of_week_Sat', 'day_of_week_Sun', 'sentiment'],
#       dtype='object')

# %%
# Check if there is any timezone info associated with the datetime column
print(df2['reviews.date'].dt.tz)
# Out:
# UTC

# %%
# Extract YYYY-MM-DD from df2['reviews.date'], save as new column and convert to date format

# Ensure 'reviews.date' is in datetime format if it's not already
# df2['reviews.date'] = pd.to_datetime(df2['reviews.date'], errors='coerce') # alternative for ISO8601 format

# Extract YYYY-MM-DD format (datetime type)
df2['date_yyyy_mm_dd'] = df2['reviews.date'].dt.date  # Keeps it as a date object, not string
df2['date_yyyy_mm_dd'] = pd.to_datetime(df2['date_yyyy_mm_dd'])  # Ensure it's datetime
# df2['date_yyyy_mm_dd'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('D').dt.to_timestamp()

# To get weekly periods.
# This will round the date to the start of the corresponding week (by default, weeks start on Sunday).
# df2['date_week_start'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('W').dt.to_timestamp() # Default: Week starts on Mon
# df2['date_week_start'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('W-SUN').dt.to_timestamp() # Week starts on Sun
df2['date_week_start'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('W-MON').dt.to_timestamp() # Week starts on Mon

# Extract YYYY-MM format (keep as a string to avoid unwanted "YYYY-MM-01" assumption)
# df2['date_yyyy_mm'] = df2['reviews.date'].dt.strftime('%Y-%m')  # Keep as string

# Extract YYYY-MM format as string (no need for .dt.month)
# Extract YYYY-MM format as a period (Year-Month) and then convert it to timestamp (first day of the month)
# df2['date_month_start'] = df2['reviews.date'].dt.to_period('M').dt.to_timestamp() # Converts date to 2025-01-01 00:00:00
df2['date_month_start'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('M').dt.to_timestamp() # Converts date to 2025-01-01 00:00:00
# df2['yyyy_mm'] = df2['reviews.date'].dt.tz_localize(None).dt.to_period('M').dt.start_time # Converts date to 2025-01

# Print column names and data types
print(df2.columns)
print(df2.dtypes)
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'name', 'postalCode', 'province', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username', 'sourceURLs', 'websites',
#        'year', 'month', 'day', 'weekofyear', 'day_of_week_Mon',
#        'day_of_week_Tue', 'day_of_week_Wed', 'day_of_week_Thu',
#        'day_of_week_Fri', 'day_of_week_Sat', 'day_of_week_Sun', 'sentiment',
#        'date_yyyy_mm_dd', 'date_week_start', 'date_month_start'],
#       dtype='object')
# id                                   object
# dateAdded                            object
# dateUpdated                          object
# address                              object
# categories                           object
# ...

# %%
print(df2['date_yyyy_mm_dd'].unique())
# Out:
# <DatetimeArray>
# ['2018-01-01 00:00:00', '2016-04-02 00:00:00', '2016-01-06 00:00:00',
#  '2016-08-22 00:00:00', '2016-03-21 00:00:00', '2016-03-15 00:00:00',
#  '2016-04-18 00:00:00', '2015-08-13 00:00:00', '2014-07-15 00:00:00',
#  '2016-07-06 00:00:00',
#  ...
#  '2010-10-12 00:00:00', '2011-10-31 00:00:00', '2012-12-23 00:00:00',
#  '2011-05-15 00:00:00', '2013-06-10 00:00:00', '2011-01-11 00:00:00',
#  '2017-09-27 00:00:00', '2013-03-20 00:00:00', '2011-07-08 00:00:00',
#  '2013-07-30 00:00:00']
# Length: 2809, dtype: datetime64[ns]

# %%
print(df2['date_week_start'].unique())
# Out:
# <DatetimeArray>
# ['2017-12-26 00:00:00', '2016-03-29 00:00:00', '2016-01-05 00:00:00',
#  '2016-08-16 00:00:00', '2016-03-15 00:00:00', '2016-04-12 00:00:00',
#  '2015-08-11 00:00:00', '2014-07-15 00:00:00', '2016-07-05 00:00:00',
#  '2017-11-07 00:00:00',
#  ...
#  '2010-01-05 00:00:00', '2007-10-16 00:00:00', '2010-04-06 00:00:00',
#  '2006-02-14 00:00:00', '2006-02-07 00:00:00', '2008-11-04 00:00:00',
#  '2004-08-10 00:00:00', '2010-02-02 00:00:00', '2006-03-07 00:00:00',
#  '2009-10-27 00:00:00']
# Length: 614, dtype: datetime64[ns]

# %%
print(df2['date_month_start'].unique())
# Out:
# <DatetimeArray>
# ['2018-01-01 00:00:00', '2016-04-01 00:00:00', '2016-01-01 00:00:00',
#  '2016-08-01 00:00:00', '2016-03-01 00:00:00', '2015-08-01 00:00:00',
#  '2014-07-01 00:00:00', '2016-07-01 00:00:00', '2017-11-01 00:00:00',
#  '2015-06-01 00:00:00',
#  ...
#  '2007-01-01 00:00:00', '2006-05-01 00:00:00', '2004-07-01 00:00:00',
#  '2005-08-01 00:00:00', '2004-04-01 00:00:00', '2006-01-01 00:00:00',
#  '2008-09-01 00:00:00', '2004-12-01 00:00:00', '2010-01-01 00:00:00',
#  '2006-02-01 00:00:00']
# Length: 174, dtype: datetime64[ns]

# %%
print(df2.columns)
print(df2.dtypes)
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'address', 'categories',
#        'primaryCategories', 'city', 'country', 'keys', 'latitude', 'longitude',
#        'name', 'postalCode', 'province', 'reviews.date', 'reviews.dateAdded',
#        'reviews.dateSeen', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username', 'sourceURLs', 'websites',
#        'year', 'month', 'day', 'weekofyear', 'day_of_week_Mon',
#        'day_of_week_Tue', 'day_of_week_Wed', 'day_of_week_Thu',
#        'day_of_week_Fri', 'day_of_week_Sat', 'day_of_week_Sun', 'sentiment',
#        'date_yyyy_mm_dd', 'date_week_start', 'date_month_start'],
#       dtype='object')
# id                                   object
# dateAdded                            object
# dateUpdated                          object
# address                              object
# categories                           object
# ...

# %%
df2[['reviews.date', 'date_yyyy_mm_dd', 'date_week_start', 'date_month_start', 'sentiment']]
# Out:
#                   reviews.date date_yyyy_mm_dd date_week_start  \
# 0    2018-01-01 00:00:00+00:00      2018-01-01      2017-12-26
# 1    2016-04-02 00:00:00+00:00      2016-04-02      2016-03-29
# 2    2016-01-06 00:00:00+00:00      2016-01-06      2016-01-05
# 3    2016-08-22 00:00:00+00:00      2016-08-22      2016-08-16
# 4    2016-03-21 00:00:00+00:00      2016-03-21      2016-03-15
# ...                        ...             ...             ...
# 9785 2015-12-24 00:00:00+00:00      2015-12-24      2015-12-22
# 9786 2015-11-17 00:00:00+00:00      2015-11-17      2015-11-17
# 9787 2016-07-06 00:00:00+00:00      2016-07-06      2016-07-05
# 9788 2016-10-26 00:00:00+00:00      2016-10-26      2016-10-25
# 9789 2017-06-29 00:00:00+00:00      2017-06-29      2017-06-27
#
#      date_month_start  sentiment
# 0          2018-01-01          0
# 1          2016-04-01          1
# 2          2016-01-01          0
# 3          2016-08-01          1
# 4          2016-03-01          0
# ...

# %%
# Create a new dataframe by dropping all columns except date_yyyy_mm_dd and sentiment.

df3 = df2[['date_yyyy_mm_dd', 'sentiment']]

# Print column names and data types
print(df3.columns)
print(df3.dtypes)
# Out:
# Index(['date_yyyy_mm_dd', 'sentiment'], dtype='object')
# date_yyyy_mm_dd    datetime64[ns]
# sentiment                   int64
# dtype: object

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df3['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Statistic: -12.111143448908674
# p-value: 1.9181150644839028e-22
# Critical Values: {'1%': -3.4310214251582605, '5%': -2.8618367291146485, '10%': -2.56692794378353}

# %% [markdown]
# Augmented Dickey-Fuller (ADF) Test Result Analysis
#
# 1. The null hypothesis of the ADF test is that the series is non-stationary.
# 2.   Since the p-value is significantly less than 0.05 (in fact, it's very close to 0), you can reject the null hypothesis and conclude that the data is stationary.
# 3.  The ADF Statistic (-12.11) is much smaller than the critical values at the 1%, 5%, and 10% levels (e.g., -3.43 at the 1% level). This further confirms that the data does not have a unit root and is indeed stationary.
# 4.  ARIMA modelling needs time series to be stationary. Since the ADF test shows that the series is stationary, therefore can proceed to do ARIMA modelling.

# %%
print(df3)
# Out:
#      date_yyyy_mm_dd  sentiment
# 0         2018-01-01          0
# 1         2016-04-02          1
# 2         2016-01-06          0
# 3         2016-08-22          1
# 4         2016-03-21          0
# ...              ...        ...
# 9785      2015-12-24          1
# 9786      2015-11-17          1
# 9787      2016-07-06          1
# 9788      2016-10-26          1
# 9789      2017-06-29          1
#
# [9771 rows x 2 columns]

# %%
# Print df3 sortby date_yyyy_mm_dd

print(df3.sort_values(by='date_yyyy_mm_dd'))
# Out:
#      date_yyyy_mm_dd  sentiment
# 1245      2003-09-01          0
# 8581      2003-09-08          0
# 1562      2003-10-20          1
# 5890      2004-01-13          1
# 1296      2004-03-19          1
# ...              ...        ...
# 7574      2019-01-29          1
# 1728      2019-01-29          1
# 3191      2019-01-29          1
# 3190      2019-01-29          1
# 2356      2019-01-30          1
#
# [9771 rows x 2 columns]

# %%
# Not used.
# Select numeric columns and compute the sum
df3_numeric = df3.select_dtypes(include=['number']).groupby(df3['date_yyyy_mm_dd']).mean()

# Select non-numeric columns (if any) and keep the first value
df3_non_numeric = df3.select_dtypes(exclude=['number']).groupby(df3['date_yyyy_mm_dd']).first()

# Merge the two back together
df3 = pd.concat([df3_numeric, df3_non_numeric], axis=1)

# %%
# Ensure the Date Index is Monotonic (Sorted): The data should be in ascending or descending order of dates. To sort the data by the date index:
# Sort data by date index
df3.sort_index(inplace=True)

# Assuming 'date_yyyy_mm_dd' is already in datetime format
df3.set_index('date_yyyy_mm_dd', inplace=True)

# Set Frequency Information: You can explicitly set the frequency for the date index. Since you're working with daily data (from date_yyyy_mm_dd), set the frequency to D (for day):
df3 = df3.asfreq('D')  # Daily frequency

# %%
# Assuming 'date_yyyy_mm_dd' is already in datetime format
# df3.set_index('date_yyyy_mm_dd', inplace=True)

# Now you can apply ARIMA using only the 'sentiment' column
y = df3['sentiment']

# ARIMA model example
from statsmodels.tsa.arima.model import ARIMA

# Define p, d, and q values
# These are the typical parameters to start with
p, d, q = 1, 1, 1  # Example values, you might need to tune these

model = ARIMA(y, order=(p, d, q))  # Set (p, d, q) after model tuning
fitted_model = model.fit()
print(fitted_model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              sentiment   No. Observations:                 5631
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -667.991
# Date:                Wed, 26 Feb 2025   AIC                           1341.982
# Time:                        12:00:54   BIC                           1361.889
# Sample:                    09-01-2003   HQIC                          1348.917
#                          - 01-30-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0287      0.022      1.285      0.199      -0.015       0.072
# ma.L1         -0.9950      0.002   -599.611      0.000      -0.998      -0.992
# sigma2         0.0940      0.002     38.007      0.000       0.089       0.099
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the historical data range
start_date_daily = df3.index[0]  # First date in dataset
end_date_daily = df3.index[-1]  # Last date in dataset

# Define the start and end dates for historical data and the forecast period
# start_date_daily = pd.Timestamp('2003-10-20 00:00:00')
# end_date_daily = pd.Timestamp('2019-01-30 00:00:00')

# Number of forecast periods (30 days ahead)
forecast_periods = 30

# Get the forecast for the next 30 days from the last observed date
forecast = fitted_model.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Create forecast index starting from the last date in the data (NOT the first date)
forecast_index = pd.date_range(start=end_date_daily + pd.Timedelta(days=1), periods=forecast_periods, freq='D')

# Plot the historical data and forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
# plt.plot(df3.index, df3['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (ARIMA) for Daily Model')
plt.legend()

# Show the plot
plt.show()

# %%
# Filter for positive sentiments (sentiment == 1)
df3_numeric_positive = df3[df3['sentiment'] == 1]

# Group by date_yyyy_mm_dd and count positive sentiments (sentiment == 1)
df3_numeric_positive_count = df3_numeric_positive.select_dtypes(include=['number']).groupby(df3['date_yyyy_mm_dd']).count()

# Select non-numeric columns (if any) and keep the first value
df3_non_numeric = df3_numeric_positive.select_dtypes(exclude=['number']).groupby(df3['date_yyyy_mm_dd']).first()

# Merge the two back together
df3_positive = pd.concat([df3_numeric_positive_count, df3_non_numeric], axis=1)


# Filter for negative sentiments (sentiment == 0)
df3_numeric_negative = df3[df3['sentiment'] == 0]

# Group by date_yyyy_mm_dd and count negative sentiments (sentiment == 0)
df3_numeric_negative_count = df3_numeric_negative.select_dtypes(include=['number']).groupby(df3['date_yyyy_mm_dd']).count()

# Select non-numeric columns (if any) and keep the first value
df3_non_numeric = df3_numeric_negative.select_dtypes(exclude=['number']).groupby(df3['date_yyyy_mm_dd']).first()

# Merge the two back together
df3_negative = pd.concat([df3_numeric_negative_count, df3_non_numeric], axis=1)

# %%
print('df3_positive:')
print(df3_positive)
print()
print('df3_negative:')
print(df3_negative)
print()
# Out:
# df3_positive:
#                  sentiment date_yyyy_mm_dd
# date_yyyy_mm_dd
# 2003-10-20               1      2003-10-20
# 2004-01-13               1      2004-01-13
# 2004-03-19               1      2004-03-19
# 2004-06-30               1      2004-06-30
# 2004-07-28               1      2004-07-28
# ...                    ...             ...
# 2019-01-25               4      2019-01-25
# 2019-01-27               1      2019-01-27
# 2019-01-28               2      2019-01-28
# 2019-01-29               5      2019-01-29
# 2019-01-30               1      2019-01-30
#
# [2554 rows x 2 columns]
#
# df3_negative:
#                  sentiment date_yyyy_mm_dd
# date_yyyy_mm_dd
# 2003-09-01               1      2003-09-01
# 2003-09-08               1      2003-09-08
# 2004-04-15               1      2004-04-15
# 2004-09-19               1      2004-09-19
# 2004-10-04               1      2004-10-04
# ...                    ...             ...
# 2019-01-14               1      2019-01-14
# ...

# %%
print("df3_positive['sentiment'].unique():")
print()
print(df3_positive['sentiment'].unique())
print()
print("df3_negative['sentiment'].unique():")
print()
print(df3_negative['sentiment'].unique())
print()
# Out:
# df3_positive['sentiment'].unique():
#
# [ 1  2  3  4  6  5  7  8 13  9 11 10 12 18 15 14 16 17 22]
#
# df3_negative['sentiment'].unique():
#
# [ 1  2  3  4  8  5  7  6 10]

# %%
print(df3_positive.shape)
print(df3_positive.columns)
print(df3_negative.shape)
print(df3_negative.columns)
# Out:
# (2554, 2)
# Index(['sentiment', 'date_yyyy_mm_dd'], dtype='object')
# (1447, 2)
# Index(['sentiment', 'date_yyyy_mm_dd'], dtype='object')

# %%
# After grouping by date_yyyy_mm_dd, should not have any duplicate rows.

# Check for duplicate dates in the index
duplicates_positive = df3_positive.index.duplicated()
print(f"Number of duplicate dates: {duplicates_positive.sum()}")

duplicates_negative = df3_negative.index.duplicated()
print(f"Number of duplicate dates: {duplicates_negative.sum()}")
# Out:
# Number of duplicate dates: 0
# Number of duplicate dates: 0

# %%
print(df3_positive.index)
print(df3_negative.index)
# Out:
# DatetimeIndex(['2003-10-20', '2004-01-13', '2004-03-19', '2004-06-30',
#                '2004-07-28', '2004-08-01', '2004-08-15', '2004-08-17',
#                '2004-09-28', '2004-11-01',
#                ...
#                '2019-01-18', '2019-01-20', '2019-01-21', '2019-01-22',
#                '2019-01-24', '2019-01-25', '2019-01-27', '2019-01-28',
#                '2019-01-29', '2019-01-30'],
#               dtype='datetime64[ns]', name='date_yyyy_mm_dd', length=2554, freq=None)
# DatetimeIndex(['2003-09-01', '2003-09-08', '2004-04-15', '2004-09-19',
#                '2004-10-04', '2004-10-17', '2004-12-31', '2005-01-20',
#                '2005-04-20', '2005-04-21',
#                ...
#                '2018-12-11', '2018-12-12', '2018-12-16', '2018-12-19',
#                '2018-12-28', '2019-01-14', '2019-01-16', '2019-01-18',
#                '2019-01-21', '2019-01-25'],
#               dtype='datetime64[ns]', name='date_yyyy_mm_dd', length=1447, freq=None)

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df3_positive['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Statistic: -2.2514458394106143
# p-value: 0.18810586048148403
# Critical Values: {'1%': -3.432941432200312, '5%': -2.8626848861611447, '10%': -2.567379466363752}

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd

def check_stationarity(series, max_diff=3, alpha=0.05):
    """
    Apply differencing iteratively until the series becomes stationary.

    Parameters:
    - series: The time series data (counts of positive sentiments).
    - max_diff: Maximum number of differencing attempts.
    - alpha: Significance level for ADF test.

    Returns:
    - A dictionary containing differenced series and ADF test results.
    """
    diff_series = series.copy()
    results = {}

    for d in range(max_diff + 1):  # Try up to max_diff differencing
        adf_result = adfuller(diff_series.dropna())
        p_value = adf_result[1]

        results[f'd={d}'] = {
            'ADF Statistic': adf_result[0],
            'p-value': p_value,
            'Critical Values': adf_result[4]
        }

        print(f'Differencing Order: {d}, p-value: {p_value}')

        if p_value < alpha:
            print(f'Series is stationary at d={d}')
            return diff_series, results  # Return the first stationary series

        # Apply differencing for next iteration
        diff_series = diff_series.diff()

    print('Series is still non-stationary after max differencing attempts.')
    return diff_series, results  # Return the last differenced series even if non-stationary

# Apply to df3_positive
diff_series, adf_results = check_stationarity(df3_positive['sentiment'])

# View ADF results for different differencing orders
for key, value in adf_results.items():
    print(f"{key}: {value}")
# Out:
# Differencing Order: 0, p-value: 0.18810586048148403
# Differencing Order: 1, p-value: 2.928451552812987e-29
# Series is stationary at d=1
# d=0: {'ADF Statistic': -2.2514458394106143, 'p-value': 0.18810586048148403, 'Critical Values': {'1%': -3.432941432200312, '5%': -2.8626848861611447, '10%': -2.567379466363752}}
# d=1: {'ADF Statistic': -16.3516546962228, 'p-value': 2.928451552812987e-29, 'Critical Values': {'1%': -3.432941432200312, '5%': -2.8626848861611447, '10%': -2.567379466363752}}

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df3_negative['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Statistic: -2.4708245407798803
# p-value: 0.1227353499136441
# Critical Values: {'1%': -3.434953749425684, '5%': -2.8635732362456845, '10%': -2.567852483484606}

# %%
# Check whether index of time series is in increasing order.

# If it prints True, your index is already sorted, and you don’t need sort_index().
print(df3_positive.index.is_monotonic_increasing)

# If it prints False, your index is not sorted, and you should run:
df3_positive.sort_index(inplace=True)
# Out:
# True

# %%
# Count number of missing days.

# Ensure index is a proper DatetimeIndex
df3_positive.index = pd.to_datetime(df3_positive.index)

# Generate a full daily date range from the min to max date
date_range = pd.date_range(start=df3_positive.index.min(), end=df3_positive.index.max(), freq='D')

# Find missing dates
missing_dates = set(date_range) - set(df3_positive.index)

# Count missing dates
num_missing_dates = len(missing_dates)

print(f"Number of missing dates: {num_missing_dates}")

# Optional: Print a few missing dates to verify
print("Some missing dates:", sorted(list(missing_dates))[:10])  # Print first 10 missing dates
# Out:
# Number of missing dates: 3028
# Some missing dates: [Timestamp('2003-10-21 00:00:00'), Timestamp('2003-10-22 00:00:00'), Timestamp('2003-10-23 00:00:00'), Timestamp('2003-10-24 00:00:00'), Timestamp('2003-10-25 00:00:00'), Timestamp('2003-10-26 00:00:00'), Timestamp('2003-10-27 00:00:00'), Timestamp('2003-10-28 00:00:00'), Timestamp('2003-10-29 00:00:00'), Timestamp('2003-10-30 00:00:00')]

# %%
# Ensure the Date Index is Monotonic (Sorted): The data should be in ascending or descending order of dates. To sort the data by the date index:
# Sort data by date index
df3_positive.sort_index(inplace=True)

# Assuming 'date_yyyy_mm_dd' is already in datetime format
df3_positive.set_index('date_yyyy_mm_dd', inplace=True)

# Set Frequency Information: You can explicitly set the frequency for the date index. Since you're working with daily data (from date_yyyy_mm_dd), set the frequency to D (for day):
df3_positive = df3_positive.asfreq('D')  # Daily frequency

# %%
print('df3.shape:', df3.shape)
print()
print('df3.columns:', df3.columns)
print()
print('Count number of rows with non-empty values:')
print(df3.count())
print()
print('Count number of rows with null values:')
print(df3.isnull().sum())
print()
print('df3:')
print(df3)
print()
# Out:
# df3.shape: (9771, 2)
#
# df3.columns: Index(['date_yyyy_mm_dd', 'sentiment'], dtype='object')
#
# Count number of rows with non-empty values:
# date_yyyy_mm_dd    9771
# sentiment          9771
# dtype: int64
#
# Count number of rows with null values:
# date_yyyy_mm_dd    0
# sentiment          0
# dtype: int64
#
# df3:
#      date_yyyy_mm_dd  sentiment
# 0         2018-01-01          0
# 1         2016-04-02          1
# 2         2016-01-06          0
# 3         2016-08-22          1
# 4         2016-03-21          0
# ...              ...        ...
# 9785      2015-12-24          1
# 9786      2015-11-17          1
# 9787      2016-07-06          1
# 9788      2016-10-26          1
# 9789      2017-06-29          1
#
# [9771 rows x 2 columns]

# %%
# Assuming 'date_yyyy_mm_dd' is already in datetime format
# df3.set_index('date_yyyy_mm_dd', inplace=True)

# Now you can apply ARIMA using only the 'sentiment' column
y = df3_positive['sentiment']

# ARIMA model example
from statsmodels.tsa.arima.model import ARIMA

# Define p, d, and q values
# These are the typical parameters to start with
p, d, q = 1, 1, 1  # Example values, you might need to tune these

model = ARIMA(y, order=(p, d, q))  # Set (p, d, q) after model tuning
fitted_model = model.fit()
print(fitted_model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              sentiment   No. Observations:                 5582
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5071.935
# Date:                Wed, 26 Feb 2025   AIC                          10149.869
# Time:                        13:57:17   BIC                          10169.750
# Sample:                    10-20-2003   HQIC                         10156.799
#                          - 01-30-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0929      0.014      6.636      0.000       0.065       0.120
# ma.L1         -0.9518      0.004   -222.201      0.000      -0.960      -0.943
# sigma2         3.0551      0.045     68.016      0.000       2.967       3.143
# ...

# %%
# Check Residuals: Plot them to see if there’s a pattern (they should be random).
import matplotlib.pyplot as plt
residuals = fitted_model.resid
plt.figure(figsize=(10,5))
plt.plot(residuals)
plt.title("Residuals of ARIMA(1,1,1) Model")
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Example SARIMA model with seasonal parameters
sarima_model = SARIMAX(df3_positive['sentiment'],
                       order=(1, 1, 1),  # ARIMA part
                       seasonal_order=(1, 1, 1, 7),  # Seasonal ARIMA part (S=7 for weekly)
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_results = sarima_model.fit()

# Print SARIMA model summary
print(sarima_results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                         sentiment   No. Observations:                 5582
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -5043.565
# Date:                           Wed, 26 Feb 2025   AIC                          10097.130
# Time:                                   13:57:43   BIC                          10130.251
# Sample:                               10-20-2003   HQIC                         10108.676
#                                     - 01-30-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0409      0.014      2.942      0.003       0.014       0.068
# ma.L1         -0.9457      0.005   -194.203      0.000      -0.955      -0.936
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMAX model without the seasonal AR term (AR(1) and MA(1) terms for seasonal)
sarima_model_no_ar_seasonal = SARIMAX(df3_positive['sentiment'], order=(1, 1, 1), seasonal_order=(0, 1, 1, 7))
sarima_results_no_ar_seasonal = sarima_model_no_ar_seasonal.fit(disp=False)

# Print the model summary
print(sarima_results_no_ar_seasonal.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                         sentiment   No. Observations:                 5582
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 7)   Log Likelihood               -5035.262
# Date:                           Wed, 26 Feb 2025   AIC                          10078.525
# Time:                                   13:57:52   BIC                          10105.028
# Sample:                               10-20-2003   HQIC                         10087.763
#                                     - 01-30-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0399      0.014      2.854      0.004       0.013       0.067
# ma.L1         -0.9442      0.005   -200.445      0.000      -0.953      -0.935
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define start and end dates for the forecast
start_date_daily = df3_positive.index[0]
# end_date_daily = df3_positive.index[-1]
end_date_daily = pd.Timestamp('2018-12-31 00:00:00')

# Generate the forecast (for example, 30 days ahead)
forecast_periods = 300  # You can adjust this as needed

# Forecasting with the SARIMA model
forecast = sarima_results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Plot the original data and the forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
# plt.plot(df3_positive.index, df3_positive['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
forecast_index = pd.date_range(start=df3_positive.index[-1] + pd.Timedelta(days=1), periods=forecast_periods, freq='D')
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (SARIMA)')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the start and end dates for historical data and the forecast period
start_date_daily = pd.Timestamp('2003-10-20 00:00:00')
end_date_daily = pd.Timestamp('2019-01-30 00:00:00')

# Number of forecast periods (30 days)
forecast_periods = 30

# Get the forecast from the SARIMA model for the next 30 days after the last date in the data
forecast = sarima_results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Create a forecast index starting from 2003-10-20 and extend for 30 days
forecast_index = pd.date_range(start=start_date_daily, periods=forecast_periods + 1, freq='D')[1:]

# Plot the historical data and forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
plt.plot(df3_positive.index, df3_positive['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (SARIMA) from 2003-10-20')
plt.legend()

# Show the plot
plt.show()

# %%
print("df3_positive['sentiment'].unique():")
print()
print(df3_positive['sentiment'].unique())
print()
print("df3_negative['sentiment'].unique():")
print()
print(df3_negative['sentiment'].unique())
print()
# Out:
# df3_positive['sentiment'].unique():
#
# [ 1. nan  2.  3.  4.  6.  5.  7.  8. 13.  9. 11. 10. 12. 18. 15. 14. 16.
#  17. 22.]
#
# df3_negative['sentiment'].unique():
#
# [ 1  2  3  4  8  5  7  6 10]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Extract the residuals from the fitted SARIMA model
# residuals = model.resid  # Incorrect: 'ARIMA' object has no attribute 'resid'
residuals = sarima_results.resid  # Use the results object from the SARIMA model

# Plot the residuals
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True, color='blue', bins=30)
plt.title("Residuals Distribution of SARIMA Model", fontsize=16)
plt.xlabel("Residuals", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.show()

# Plot the residuals over time (for autocorrelation check)
plt.figure(figsize=(10, 6))
plt.plot(residuals, color='red')
plt.title("Residuals over Time", fontsize=16)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Residuals", fontsize=12)
plt.show()

# Optional: Plot the ACF and PACF of the residuals to check autocorrelation
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# ACF plot of residuals
plot_acf(residuals, lags=50)
plt.title("ACF of Residuals", fontsize=16)
plt.show()

# PACF plot of residuals
plot_pacf(residuals, lags=50)
plt.title("PACF of Residuals", fontsize=16)
plt.show()

# %%
# Create a new dataframe by dropping all columns except date_week_start and sentiment.

df4 = df2[['date_week_start', 'sentiment']]

# Print column names and data types
print(df4.columns)
print(df4.dtypes)
# Out:
# Index(['date_week_start', 'sentiment'], dtype='object')
# date_week_start    datetime64[ns]
# sentiment                   int64
# dtype: object

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df4['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Statistic: -12.111143448908674
# p-value: 1.9181150644839028e-22
# Critical Values: {'1%': -3.4310214251582605, '5%': -2.8618367291146485, '10%': -2.56692794378353}

# %%
# Select numeric columns and compute the sum
df4_numeric = df4.select_dtypes(include=['number']).groupby(df4['date_week_start']).mean()

# Select non-numeric columns (if any) and keep the first value
df4_non_numeric = df4.select_dtypes(exclude=['number']).groupby(df4['date_week_start']).first()

# Merge the two back together
df4 = pd.concat([df4_numeric, df4_non_numeric], axis=1)

# %%
print(df4.shape)
print(df4.columns)
# Out:
# (614, 2)
# Index(['sentiment', 'date_week_start'], dtype='object')

# %%
# After grouping by date_week_start, should not have any duplicate rows.

# Check for duplicate dates in the index
duplicates = df4.index.duplicated()
print(f"Number of duplicate dates: {duplicates.sum()}")

# %%
print(df4)
# Out:
#                  sentiment date_week_start
# date_week_start
# 2003-08-26        0.000000      2003-08-26
# 2003-09-02        0.000000      2003-09-02
# 2003-10-14        1.000000      2003-10-14
# 2004-01-13        1.000000      2004-01-13
# 2004-03-16        1.000000      2004-03-16
# ...                    ...             ...
# 2019-01-01        1.000000      2019-01-01
# 2019-01-08        0.833333      2019-01-08
# 2019-01-15        0.785714      2019-01-15
# 2019-01-22        0.909091      2019-01-22
# 2019-01-29        1.000000      2019-01-29
#
# [614 rows x 2 columns]

# %%
df4.index
# Out:
# DatetimeIndex(['2003-08-26', '2003-09-02', '2003-10-14', '2004-01-13',
#                '2004-03-16', '2004-04-13', '2004-06-29', '2004-07-27',
#                '2004-08-10', '2004-08-17',
#                ...
#                '2018-11-27', '2018-12-04', '2018-12-11', '2018-12-18',
#                '2018-12-25', '2019-01-01', '2019-01-08', '2019-01-15',
#                '2019-01-22', '2019-01-29'],
#               dtype='datetime64[ns]', name='date_week_start', length=614, freq=None)

# %%
# Check whether index of time series is in increasing order.

# If it prints True, your index is already sorted, and you don’t need sort_index().
print(df4.index.is_monotonic_increasing)

# If it prints False, your index is not sorted, and you should run:
df4.sort_index(inplace=True)
# Out:
# True

# %%
# Count number of missing weeks.

# Ensure index is a proper DatetimeIndex
df4.index = pd.to_datetime(df4.index)

# Generate a full weekly date range (start of each week, where weeks start on Monday)
date_range = pd.date_range(start=df4.index.min(), end=df4.index.max(), freq='W-MON')  # 'W-MON' for Week Start (Monday)

# Find missing weeks
missing_weeks = set(date_range) - set(df4.index)

# Count missing weeks
num_missing_weeks = len(missing_weeks)

print(f"Number of missing weeks: {num_missing_weeks}")

# Optional: Print a few missing weeks to verify
print("Some missing weeks:", sorted(list(missing_weeks))[:10])  # Print first 10 missing weeks
# Out:
# Number of missing weeks: 805
# Some missing weeks: [Timestamp('2003-09-01 00:00:00'), Timestamp('2003-09-08 00:00:00'), Timestamp('2003-09-15 00:00:00'), Timestamp('2003-09-22 00:00:00'), Timestamp('2003-09-29 00:00:00'), Timestamp('2003-10-06 00:00:00'), Timestamp('2003-10-13 00:00:00'), Timestamp('2003-10-20 00:00:00'), Timestamp('2003-10-27 00:00:00'), Timestamp('2003-11-03 00:00:00')]

# %%
# Ensure the Date Index is Monotonic (Sorted): Sort data by date index
df4.sort_index(inplace=True)

# Assuming 'date_week_start' is already in datetime format
df4.set_index('date_week_start', inplace=True)

# Set Frequency Information: Set the frequency to weekly (start of each week, Monday)
# df4 = df4.asfreq('W-MON')  # 'W-MON' for weeks starting on Monday
df4 = df4.asfreq('W-TUE')  # 'W-TUE' for weeks starting on Monday

# %%
print('df4.shape:', df4.shape)
print()
print('df4.columns:', df4.columns)
print()
print('Count number of rows with non-empty values:')
print(df4.count())
print()
print('Count number of rows with null values:')
print(df4.isnull().sum())
print()
print('df4:')
print(df4)
print()

# %%
print("df4['sentiment'].unique():")
print()
print(df4['sentiment'].unique())
print()

# %%
# Assuming 'date_week_start' is already in datetime format
# df4.set_index('date_week_start', inplace=True)

# Now you can apply ARIMA using only the 'sentiment' column
y = df4['sentiment']

# ARIMA model example
from statsmodels.tsa.arima.model import ARIMA

# Define p, d, and q values
# These are the typical parameters to start with
p, d, q = 1, 1, 1  # Example values, you might need to tune these

model = ARIMA(y, order=(p, d, q))  # Set (p, d, q) after model tuning
fitted_model = model.fit()
print(fitted_model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              sentiment   No. Observations:                  806
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -26.889
# Date:                Wed, 26 Feb 2025   AIC                             59.779
# Time:                        12:09:44   BIC                             73.851
# Sample:                    08-26-2003   HQIC                            65.183
#                          - 01-29-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0020      0.040      0.049      0.961      -0.076       0.080
# ma.L1         -0.9858      0.007   -145.267      0.000      -0.999      -0.973
# sigma2         0.0635      0.003     18.943      0.000       0.057       0.070
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Resample the data to weekly frequency (if needed)
df3_weekly = df3['sentiment'].resample('W').mean()

# Define historical data range for weekly model
start_date_weekly = df3_weekly.index[0]  # First date in dataset
end_date_weekly = df3_weekly.index[-1]  # Last date in dataset

# Number of forecast periods (30 weeks ahead)
forecast_periods = 12

# Get the forecast for the next 30 weeks
forecast = fitted_model.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Create forecast index starting from the last date in the data (weekly intervals)
forecast_index = pd.date_range(start=end_date_weekly + pd.Timedelta(weeks=1), periods=forecast_periods, freq='W')

# Plot the historical data and forecast
plt.figure(figsize=(10, 6))

# Plot the historical weekly data
# plt.plot(df3_weekly.index, df3_weekly, label='Historical Sentiment (Weekly)', color='blue')

# Plot the forecasted data
plt.plot(forecast_index, forecast_mean, label='Forecast (Weekly)', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (ARIMA) for Weekly Model')
plt.legend()

# Show the plot
plt.show()

# %%
# Check Residuals: Plot them to see if there’s a pattern (they should be random).
import matplotlib.pyplot as plt
residuals = fitted_model.resid
plt.figure(figsize=(10,5))
plt.plot(residuals)
plt.title("Residuals of ARIMA(1,1,1) Model")
plt.show()

# %%
# Create a new dataframe by dropping all columns except date_month_start and sentiment.

df5 = df2[['date_month_start', 'sentiment']]

# Print column names and data types
print(df5.columns)
print(df5.dtypes)
# Out:
# Index(['date_month_start', 'sentiment'], dtype='object')
# date_month_start    datetime64[ns]
# sentiment                    int64
# dtype: object

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df5['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])

# %%
# Select numeric columns and compute the sum
df5_numeric = df5.select_dtypes(include=['number']).groupby(df5['date_month_start']).mean()

# Select non-numeric columns (if any) and keep the first value
df5_non_numeric = df5.select_dtypes(exclude=['number']).groupby(df5['date_month_start']).first()

# Merge the two back together
df5 = pd.concat([df5_numeric, df5_non_numeric], axis=1)

# %%
print(df5.shape)
print(df5.columns)

# %%
# After grouping by date_month_start, should not have any duplicate rows.

# Check for duplicate dates in the index
duplicates = df5.index.duplicated()
print(f"Number of duplicate dates: {duplicates.sum()}")

# %%
print(df5)

# %%
df5.index

# %%
# Check whether index of time series is in increasing order.

# If it prints True, your index is already sorted, and you don’t need sort_index().
print(df5.index.is_monotonic_increasing)

# If it prints False, your index is not sorted, and you should run:
df5.sort_index(inplace=True)
# Out:
# True

# %%
# Count number of missing months.

# Ensure index is a proper DatetimeIndex
df5.index = pd.to_datetime(df5.index)

# Generate a full monthly date range (start of each month)
date_range = pd.date_range(start=df5.index.min(), end=df4.index.max(), freq='MS')  # 'MS' for Month Start

# Find missing months
missing_months = set(date_range) - set(df5.index)

# Count missing months
num_missing_months = len(missing_months)

print(f"Number of missing months: {num_missing_months}")

# Optional: Print a few missing months to verify
print("Some missing months:", sorted(list(missing_months))[:10])  # Print first 10 missing months
# Out:
# Number of missing months: 11
# Some missing months: [Timestamp('2003-11-01 00:00:00'), Timestamp('2003-12-01 00:00:00'), Timestamp('2004-02-01 00:00:00'), Timestamp('2004-05-01 00:00:00'), Timestamp('2005-02-01 00:00:00'), Timestamp('2005-05-01 00:00:00'), Timestamp('2005-07-01 00:00:00'), Timestamp('2005-09-01 00:00:00'), Timestamp('2005-11-01 00:00:00'), Timestamp('2006-04-01 00:00:00')]

# %%
# Ensure the Date Index is Monotonic (Sorted): Sort data by date index
df5.sort_index(inplace=True)

# Assuming 'date_month_start' is already in datetime format
df5.set_index('date_month_start', inplace=True)

# Set the frequency to monthly
df5 = df5.asfreq('MS')  # 'MS': Start of the month (first day of each month).

# %%
print('df5.shape:', df5.shape)
print()
print('df5.columns:', df5.columns)
print()
print('Count number of rows with non-empty values:')
print(df5.count())
print()
print('Count number of rows with null values:')
print(df5.isnull().sum())
print()
print('df5:')
print(df5)
print()

# %%
print("df5['sentiment'].unique():")
print()
print(df5['sentiment'].unique())
print()

# %%
# Assuming 'date_week_start' is already in datetime format
# df5.set_index('date_week_start', inplace=True)

# Now you can apply ARIMA using only the 'sentiment' column
y = df5['sentiment']

# ARIMA model example
from statsmodels.tsa.arima.model import ARIMA

# Define p, d, and q values
# These are the typical parameters to start with
p, d, q = 1, 1, 1  # Example values, you might need to tune these

model = ARIMA(y, order=(p, d, q))  # Set (p, d, q) after model tuning
fitted_model = model.fit()
print(fitted_model.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:              sentiment   No. Observations:                  185
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                  -4.498
# Date:                Wed, 26 Feb 2025   AIC                             14.995
# Time:                        12:15:16   BIC                             24.640
# Sample:                    09-01-2003   HQIC                            18.904
#                          - 01-01-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0001      0.061      0.002      0.999      -0.120       0.121
# ma.L1         -0.9531      0.035    -27.517      0.000      -1.021      -0.885
# sigma2         0.0608      0.005     11.560      0.000       0.050       0.071
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Resample the data to monthly frequency (if needed)
df3_monthly = df3['sentiment'].resample('M').mean()

# Define historical data range for monthly model
start_date_monthly = df3_monthly.index[0]  # First date in dataset
end_date_monthly = df3_monthly.index[-1]  # Last date in dataset

# Number of forecast periods (12 months ahead)
forecast_periods = 12

# Get the forecast for the next 12 months
forecast = fitted_model.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Create forecast index starting from the last date in the data (monthly intervals)
forecast_index = pd.date_range(start=end_date_monthly + pd.Timedelta(days=1), periods=forecast_periods, freq='M')

# Plot the historical data and forecast
plt.figure(figsize=(10, 6))

# Plot the historical monthly data
# plt.plot(df3_monthly.index, df3_monthly, label='Historical Sentiment (Monthly)', color='blue')

# Plot the forecasted data
plt.plot(forecast_index, forecast_mean, label='Forecast (Monthly)', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (ARIMA) for Monthly Model')
plt.legend()

# Show the plot
plt.show()
# Out:
# <ipython-input-146-20dc4f1eec32>:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df3_monthly = df3['sentiment'].resample('M').mean()
# <ipython-input-146-20dc4f1eec32>:20: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   forecast_index = pd.date_range(start=end_date_monthly + pd.Timedelta(days=1), periods=forecast_periods, freq='M')

# %%
# Check Residuals: Plot them to see if there’s a pattern (they should be random).
import matplotlib.pyplot as plt
residuals = fitted_model.resid
plt.figure(figsize=(10,5))
plt.plot(residuals)
plt.title("Residuals of ARIMA(1,1,1) Model")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.arima.model import ARIMA

# Safe MAPE calculation to avoid division by zero or very small values
def safe_mape(y_true, y_pred, epsilon=1e-10):
    # Avoid division by zero by adding a small epsilon
    return np.mean(np.abs((y_true - y_pred) / (y_true + epsilon))) * 100

# Function to evaluate forecast performance
def evaluate_forecast(y_true, y_pred):
    # MAE (Mean Absolute Error)
    mae = mean_absolute_error(y_true, y_pred)
    # MSE (Mean Squared Error)
    mse = mean_squared_error(y_true, y_pred)
    # RMSE (Root Mean Squared Error)
    rmse = np.sqrt(mse)
    # Safe MAPE (Mean Absolute Percentage Error)
    mape = safe_mape(y_true, y_pred)

    return mae, mse, rmse, mape

# Dictionary to store results for each model
model_results = {
    'daily': {
        'model': None,
        'mae': None,
        'mse': None,
        'rmse': None,
        'mape': None
    },
    'weekly': {
        'model': None,
        'mae': None,
        'mse': None,
        'rmse': None,
        'mape': None
    },
    'monthly': {
        'model': None,
        'mae': None,
        'mse': None,
        'rmse': None,
        'mape': None
    }
}

# 1. **Daily Model** - Fit the model and store the results
# Assuming 'df3' is your daily DataFrame and 'y_true_daily' is the true sentiment values for the test set

y_daily = df3['sentiment']
model_daily = ARIMA(y_daily, order=(1, 1, 1))
fitted_model_daily = model_daily.fit()
model_results['daily']['model'] = fitted_model_daily

# Get predicted values from the fitted model (adjust as needed)
start_date_daily = df3.index[0]
end_date_daily = df3.index[-1]
y_pred_daily = fitted_model_daily.predict(start=start_date_daily, end=end_date_daily, dynamic=False)

# Assuming y_true_daily is the actual values for the test set
y_true_daily = df3['sentiment'].dropna()  # Drop NaN values for consistency
y_pred_daily = y_pred_daily[:len(y_true_daily)]  # Ensure same length for comparison

# Evaluate the daily forecast
mae_daily, mse_daily, rmse_daily, mape_daily = evaluate_forecast(y_true_daily, y_pred_daily)
model_results['daily']['mae'] = mae_daily
model_results['daily']['mse'] = mse_daily
model_results['daily']['rmse'] = rmse_daily
model_results['daily']['mape'] = mape_daily

# 2. **Weekly Model** - Fit the model and store the results
# Assuming 'df4' is your weekly DataFrame and 'y_true_weekly' is the true sentiment values for the test set

y_weekly = df4['sentiment']
model_weekly = ARIMA(y_weekly, order=(1, 1, 1))
fitted_model_weekly = model_weekly.fit()
model_results['weekly']['model'] = fitted_model_weekly

# Get predicted values for weekly model (adjust as necessary)
start_date_weekly = df4.index[0]
end_date_weekly = df4.index[-1]
y_pred_weekly = fitted_model_weekly.predict(start=start_date_weekly, end=end_date_weekly, dynamic=False)

# Assuming y_true_weekly is the actual values for the test set
y_true_weekly = df4['sentiment'].dropna()  # Drop NaN values for consistency
y_pred_weekly = y_pred_weekly[:len(y_true_weekly)]  # Ensure same length for comparison

# Evaluate the weekly forecast
mae_weekly, mse_weekly, rmse_weekly, mape_weekly = evaluate_forecast(y_true_weekly, y_pred_weekly)
model_results['weekly']['mae'] = mae_weekly
model_results['weekly']['mse'] = mse_weekly
model_results['weekly']['rmse'] = rmse_weekly
model_results['weekly']['mape'] = mape_weekly

# 3. **Monthly Model** - Fit the model and store the results
# Assuming 'df5' is your monthly DataFrame and 'y_true_monthly' is the true sentiment values for the test set

y_monthly = df5['sentiment']
model_monthly = ARIMA(y_monthly, order=(1, 1, 1))
fitted_model_monthly = model_monthly.fit()
model_results['monthly']['model'] = fitted_model_monthly

# Get predicted values for monthly model (adjust as necessary)
start_date_monthly = df5.index[0]
end_date_monthly = df5.index[-1]
y_pred_monthly = fitted_model_monthly.predict(start=start_date_monthly, end=end_date_monthly, dynamic=False)

# Assuming y_true_monthly is the actual values for the test set
y_true_monthly = df5['sentiment'].dropna()  # Drop NaN values for consistency
y_pred_monthly = y_pred_monthly[:len(y_true_monthly)]  # Ensure same length for comparison

# Evaluate the monthly forecast
mae_monthly, mse_monthly, rmse_monthly, mape_monthly = evaluate_forecast(y_true_monthly, y_pred_monthly)
model_results['monthly']['mae'] = mae_monthly
model_results['monthly']['mse'] = mse_monthly
model_results['monthly']['rmse'] = rmse_monthly
model_results['monthly']['mape'] = mape_monthly

# Print the results for all models
print("Model Performance Metrics:")
for model, metrics in model_results.items():
    print(f"\n{model.capitalize()} Model:")
    print(f"  MAE: {metrics['mae']}")
    print(f"  MSE: {metrics['mse']}")
    print(f"  RMSE: {metrics['rmse']}")
    print(f"  MAPE: {metrics['mape']}")

# Optionally, you can store the results in a DataFrame for easier comparison
df_results = pd.DataFrame.from_dict(model_results, orient='index')
print(df_results)
# Out:
# Model Performance Metrics:
#
# Daily Model:
#   MAE: 0.2879626375468096
#   MSE: 0.11953220956932627
#   RMSE: 0.34573430487778656
#   MAPE: 176923535655.1768
#
# Weekly Model:
#   MAE: 0.19510328979938357
#   MSE: 0.07357123292990628
#   RMSE: 0.2712401757297511
#   MAPE: 60469078253.62901
#
# Monthly Model:
#   MAE: 0.16333462715799088
#   MSE: 0.06417833230564848
#   RMSE: 0.2533344277938719
#   MAPE: 49417206118.06037
#                                                      model       mae  \
# daily    <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.287963
# weekly   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.195103
# monthly  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.163335
#
#               mse      rmse          mape
# daily    0.119532  0.345734  1.769235e+11
# weekly   0.073571  0.271240  6.046908e+10
# monthly  0.064178  0.253334  4.941721e+10

# %%
df_results
# Out:
#                                                      model       mae  \
# daily    <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.287963
# weekly   <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.195103
# monthly  <statsmodels.tsa.arima.model.ARIMAResultsWrapp...  0.163335
#
#               mse      rmse          mape
# daily    0.119532  0.345734  1.769235e+11
# weekly   0.073571  0.271240  6.046908e+10
# monthly  0.064178  0.253334  4.941721e+10

# %%
df3_positive.index[0]

# %%
df3_positive.index[-1]

# %%
# Create a new dataframe by dropping all columns except date_yyyy_mm_dd and sentiment.

df3 = df2[['date_yyyy_mm_dd', 'sentiment']]

# Print column names and data types
print(df3.columns)
print(df3.dtypes)
# Out:
# Index(['date_yyyy_mm_dd', 'sentiment'], dtype='object')
# date_yyyy_mm_dd    datetime64[ns]
# sentiment                   int64
# dtype: object

# %%
# Filter for positive sentiments (sentiment == 1)
df3_numeric_positive = df3[df3['sentiment'] == 1]

# Group by date_yyyy_mm_dd and count positive sentiments (sentiment == 1)
df3_numeric_positive_count = df3_numeric_positive.select_dtypes(include=['number']).groupby(df3['date_yyyy_mm_dd']).count()

# Select non-numeric columns (if any) and keep the first value
df3_non_numeric = df3_numeric_positive.select_dtypes(exclude=['number']).groupby(df3['date_yyyy_mm_dd']).first()

# Merge the two back together
df3_positive = pd.concat([df3_numeric_positive_count, df3_non_numeric], axis=1)


# Filter for negative sentiments (sentiment == 0)
df3_numeric_negative = df3[df3['sentiment'] == 0]

# Group by date_yyyy_mm_dd and count negative sentiments (sentiment == 0)
df3_numeric_negative_count = df3_numeric_negative.select_dtypes(include=['number']).groupby(df3['date_yyyy_mm_dd']).count()

# Select non-numeric columns (if any) and keep the first value
df3_non_numeric = df3_numeric_negative.select_dtypes(exclude=['number']).groupby(df3['date_yyyy_mm_dd']).first()

# Merge the two back together
df3_negative = pd.concat([df3_numeric_negative_count, df3_non_numeric], axis=1)

# %%
print("df3_positive['sentiment'].unique():")
print()
print(df3_positive['sentiment'].unique())
print()
print("df3_negative['sentiment'].unique():")
print()
print(df3_negative['sentiment'].unique())
print()
# Out:
# df3_positive['sentiment'].unique():
#
# [ 1  2  3  4  6  5  7  8 13  9 11 10 12 18 15 14 16 17 22]
#
# df3_negative['sentiment'].unique():
#
# [ 1  2  3  4  8  5  7  6 10]

# %%
# Augmented Dickey-Fuller (ADF) test. The null hypothesis of the ADF test is that the series is non-stationary.
from statsmodels.tsa.stattools import adfuller

# Perform ADF test on the 'sentiment' column (you can replace with your target variable)
result = adfuller(df3_negative['sentiment'])

# Print the results
print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:", result[4])
# Out:
# ADF Statistic: -2.4708245407798803
# p-value: 0.1227353499136441
# Critical Values: {'1%': -3.434953749425684, '5%': -2.8635732362456845, '10%': -2.567852483484606}

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd

def check_stationarity(series, max_diff=3, alpha=0.05):
    """
    Apply differencing iteratively until the series becomes stationary.

    Parameters:
    - series: The time series data (counts of positive sentiments).
    - max_diff: Maximum number of differencing attempts.
    - alpha: Significance level for ADF test.

    Returns:
    - A dictionary containing differenced series and ADF test results.
    """
    diff_series = series.copy()
    results = {}

    for d in range(max_diff + 1):  # Try up to max_diff differencing
        adf_result = adfuller(diff_series.dropna())
        p_value = adf_result[1]

        results[f'd={d}'] = {
            'ADF Statistic': adf_result[0],
            'p-value': p_value,
            'Critical Values': adf_result[4]
        }

        print(f'Differencing Order: {d}, p-value: {p_value}')

        if p_value < alpha:
            print(f'Series is stationary at d={d}')
            return diff_series, results  # Return the first stationary series

        # Apply differencing for next iteration
        diff_series = diff_series.diff()

    print('Series is still non-stationary after max differencing attempts.')
    return diff_series, results  # Return the last differenced series even if non-stationary

# Apply to df3_positive
diff_series, adf_results = check_stationarity(df3_positive['sentiment'])

# View ADF results for different differencing orders
for key, value in adf_results.items():
    print(f"{key}: {value}")
# Out:
# Differencing Order: 0, p-value: 0.18810586048148403
# Differencing Order: 1, p-value: 2.928451552812987e-29
# Series is stationary at d=1
# d=0: {'ADF Statistic': -2.2514458394106143, 'p-value': 0.18810586048148403, 'Critical Values': {'1%': -3.432941432200312, '5%': -2.8626848861611447, '10%': -2.567379466363752}}
# d=1: {'ADF Statistic': -16.3516546962228, 'p-value': 2.928451552812987e-29, 'Critical Values': {'1%': -3.432941432200312, '5%': -2.8626848861611447, '10%': -2.567379466363752}}

# %%
# Ensure the Date Index is Monotonic (Sorted): The data should be in ascending or descending order of dates. To sort the data by the date index:
# Sort data by date index
df3_negative.sort_index(inplace=True)

# Assuming 'date_yyyy_mm_dd' is already in datetime format
df3_negative.set_index('date_yyyy_mm_dd', inplace=True)

# Set Frequency Information: You can explicitly set the frequency for the date index. Since you're working with daily data (from date_yyyy_mm_dd), set the frequency to D (for day):
df3_negative = df3_negative.asfreq('D')  # Daily frequency

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Example SARIMA model with seasonal parameters
sarima_model = SARIMAX(df3_negative['sentiment'],
                       order=(1, 1, 1),  # ARIMA part
                       seasonal_order=(1, 1, 1, 7),  # Seasonal ARIMA part (S=7 for weekly)
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_results = sarima_model.fit()

# Print SARIMA model summary
print(sarima_results.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                         sentiment   No. Observations:                 5626
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood               -1892.603
# Date:                           Wed, 26 Feb 2025   AIC                           3795.206
# Time:                                   13:48:45   BIC                           3828.366
# Sample:                               09-01-2003   HQIC                          3806.761
#                                     - 01-25-2019
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0196      0.025     -0.798      0.425      -0.068       0.029
# ma.L1         -0.9673      0.005   -198.971      0.000      -0.977      -0.958
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Fit the SARIMAX model without the seasonal AR term (AR(1) and MA(1) terms for seasonal)
sarima_model_no_ar_seasonal = SARIMAX(df3_negative['sentiment'], order=(1, 1, 1), seasonal_order=(0, 1, 1, 7))
sarima_results_no_ar_seasonal = sarima_model_no_ar_seasonal.fit(disp=False)

# Print the model summary
print(sarima_results_no_ar_seasonal.summary())

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define start and end dates for the forecast
start_date_daily = df3_negative.index[0]
end_date_daily = df3_negative.index[-1]
# end_date_daily = pd.Timestamp('2018-12-31 00:00:00')

# Generate the forecast (for example, 30 days ahead)
forecast_periods = 30  # You can adjust this as needed

# Forecasting with the SARIMA model
forecast = sarima_results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Plot the original data and the forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
# plt.plot(df3_negative.index, df3_negative['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
forecast_index = pd.date_range(start=df3_negative.index[-1] + pd.Timedelta(days=1), periods=forecast_periods, freq='D')
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (SARIMA)')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define start and end dates for the forecast
start_date_daily = df3_positive.index[0]
# end_date_daily = df3_positive.index[-1]
end_date_daily = pd.Timestamp('2018-12-31 00:00:00')

# Generate the forecast (for example, 30 days ahead)
forecast_periods = 300  # You can adjust this as needed

# Forecasting with the SARIMA model
forecast = sarima_results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Plot the original data and the forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
plt.plot(df3_positive.index, df3_positive['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
forecast_index = pd.date_range(start=df3_positive.index[-1] + pd.Timedelta(days=1), periods=forecast_periods, freq='D')
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (SARIMA)')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the start and end dates for historical data and the forecast period
start_date_daily = pd.Timestamp('2003-10-20 00:00:00')
end_date_daily = pd.Timestamp('2019-01-30 00:00:00')

# Number of forecast periods (30 days)
forecast_periods = 30

# Get the forecast from the SARIMA model for the next 30 days after the last date in the data
forecast = sarima_results.get_forecast(steps=forecast_periods)
forecast_mean = forecast.predicted_mean
forecast_conf_int = forecast.conf_int()

# Create a forecast index starting from 2003-10-20 and extend for 30 days
forecast_index = pd.date_range(start=start_date_daily, periods=forecast_periods + 1, freq='D')[1:]

# Plot the historical data and forecast
plt.figure(figsize=(10, 6))

# Plot the historical data
plt.plot(df3_positive.index, df3_positive['sentiment'], label='Historical Sentiment', color='blue')

# Plot the forecasted data
plt.plot(forecast_index, forecast_mean, label='Forecast', color='red')

# Plot the forecast confidence intervals
plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='pink', alpha=0.3)

# Adding labels and title
plt.xlabel('Date')
plt.ylabel('Sentiment')
plt.title('Sentiment Forecast (SARIMA) from 2003-10-20')
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-7aa2059920ea> in <cell line: 0>()
#      21
#      22 # Plot the historical data
# ---> 23 plt.plot(df3_positive.index, df3_positive['sentiment'], label='Historical Sentiment', color='blue')
#      24
#      25 # Plot the forecasted data
#
# NameError: name 'df3_positive' is not defined
